# %% [markdown]
# #Setup

# %%
# !git clone https://github.com/aliswh/lastfm
# !cd lastfm; pip install -r requirements.txt
# !wget https://storage.googleapis.com/hadoop-lib/gcs/gcs-connector-hadoop3-latest.jar
# !cp gcs-connector-hadoop3-latest.jar /usr/local/lib/python3.7/dist-packages/pyspark/jars

# %%
# !cd lastfm; git pull

# %%
import pyspark
from pyspark.sql import SparkSession

from lastfm.src.ingestion_layer.googlestorage import *
from lastfm.src.ingestion_layer.pylastsource import *
from lastfm.src.ingestion_layer.batchwriter import *
from lastfm.src.ingestion_layer.pysparkreader import *
from lastfm.src.ingestion_layer.config import *

from functools import reduce
from operator import add
import datetime

# %%
spark = SparkSession.builder.appName('A4BD Project').getOrCreate()
sc = pyspark.SparkContext.getOrCreate()
reader = PySparkReader(sc)
storage = GoogleStorageJSON('./lastfm/src/ingestion_layer/creds.json',BUCKET_NAME)

# %% [markdown]
# #Code

# %%
#@markdown Helper functions
def to_date(x):
  return datetime.datetime.strptime(x, '%d %b %Y, %H:%M').date()

def filter_date(rdd, date):
  #today = datetime.date.today()
  today = datetime.datetime(2022, 2, 21).date() # To have consistent results
  def today_f(rdd):
    return rdd.filter(lambda x: to_date(x['date']) == today)
  def yesterday_f(rdd):
    yesterday = today - datetime.timedelta(days=1)
    return rdd.filter(lambda x: to_date(x['date']) == yesterday)
  def last_week_f(rdd):
    last_week = today - datetime.timedelta(days=6)
    return rdd.filter(lambda x: to_date(x['date']) >= last_week)
  def last_month_f(rdd):
    last_month = today - datetime.timedelta(days=30)
    return rdd.filter(lambda x: to_date(x['date']) >= last_month)
  filters = {'today':today_f,
             'yesterday':yesterday_f,
             'last week':last_week_f,
             'last month':last_month_f}
  return filters[date](rdd)

def topN(x, y, idx, reverse, top):
  x = [x] if type(x)!=list else x
  y = [y] if type(y)!=list else y
  return sorted([*x,*y], reverse = reverse, key=lambda x:x[idx])[:top]

def top_hits(rdd, top):
  rdd = rdd.map(lambda x: ((x['id'],x['title'],x['artist']),1))\
           .groupByKey()\
           .mapValues(sum)\
           .map(lambda x: (x[0][1],x[0][2],x[1]))
  try:
    reduced = rdd.reduce(lambda x,y: topN(x,y,2,reverse=True,top=top))
    reduced = [reduced] if type(reduced)!=list else reduced
    return reduced
  except Exception as e:
    print(e)
    return []

def join_tracks_info(rdd, tracks_rdd):
  rdd = rdd.map(lambda x: (x['id'],x))
  tracks_rdd = tracks_rdd.map(lambda x: (x['id'],x))
  rdd = rdd.join(tracks_rdd)\
           .mapValues(lambda x: dict(list(x[0].items()) + list(x[1].items())))
  return rdd

def print_hit(hit):
  print(hit)
  print(f'Title: {hit[0]}')
  print(f'Artist: {hit[1]}')
  print(f'Count: {hit[2]}')

def top_hits_date_genre(rdd, top, date='', genre='', tracks_rdd=None, bool_print=False):
  if date != '':
    rdd = filter_date(rdd, date)
    if bool_print:
      print(f'[{date} greatest hits]')
  elif bool_print:
    print('[all time greatest hits]')

  if genre != '':
    if tracks_rdd == None:
      print('No tracks info provided')
      print()
      return
    elif bool_print:
      print(f'[{genre}]')
    rdd = join_tracks_info(rdd, tracks_rdd)
    rdd = rdd.map(lambda x: x[1])
    rdd = rdd.filter(lambda x: x['tags'] and genre in x['tags'])

  hits = top_hits(rdd, top)
  if bool_print:
    for hit in hits:
      print_hit(hit)
    print()
  return hits

def top_hits_all_dates(rdd, top=3, genres=[''], tracks_rdd=None, bool_print=False):
  dates = ['today','yesterday','last week','last month']
  if genres != ['']:
    genre_dict = {genre:{} for genre in genres}
  else:
    genre_dict = {}
  ret_hits = {date:genre_dict.copy() for date in dates}
  for date in dates:
    for genre in genres:
      res = top_hits_date_genre(rdd, top, date, genre, tracks_rdd, bool_print)
      if genres != ['']:
        ret_hits[date][genre] = res
      else:
        ret_hits[date] = res
  return ret_hits

# %%
#Data gathering
recent_tracks_rdd = reader.read('recent_tracks',dir=True).map(lambda x: x['recent_tracks']).flatMap(lambda x: x).cache()
tracks_rdd = reader.read('tracks',dir=True).cache()
global_top_tags_rdd = reader.read('global_top_tags',dir=False).cache()

# %%
#Local speed-up (doesn't work for large datasets)
recent_tracks_rdd = sc.parallelize(recent_tracks_rdd.collect())
tracks_rdd = sc.parallelize(tracks_rdd.collect())
global_top_tags_rdd = sc.parallelize(global_top_tags_rdd.collect())

# %%
top = 3
n_genres = 5
genres = set(map(lambda x: x[0], sorted(global_top_tags_rdd.collect()[0].items(), key = lambda x: x[1], reverse=True)[:n_genres]))

all_hits_dict = top_hits_all_dates(recent_tracks_rdd, top, bool_print=True)
genre_hits_dict = top_hits_all_dates(recent_tracks_rdd, top, genres, tracks_rdd, True)
# Out:
# [today greatest hits]
# ('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 5)
# Title: Tin Pan Alley (AKA Roughest Place in Town)
# Artist: Stevie Ray Vaughan
# Count: 5
# ("Goin' Down South", 'Kenny Brown', 2)
# Title: Goin' Down South
# Artist: Kenny Brown
# Count: 2
# ('While My Guitar Gently Weeps', 'The Beatles', 2)
# Title: While My Guitar Gently Weeps
# Artist: The Beatles
# Count: 2
#
# [yesterday greatest hits]
# ('Souled Out On You', 'Robert Finley', 6)
# Title: Souled Out On You
# Artist: Robert Finley
# Count: 6
# ('Make Me Feel Alright', 'Robert Finley', 3)
# Title: Make Me Feel Alright
# Artist: Robert Finley
# Count: 3
# ('Better Than I Treat Myself', 'Robert Finley', 3)
# Title: Better Than I Treat Myself
# Artist: Robert Finley
# Count: 3
#
# [last week greatest hits]
# ('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 6)
# Title: Tin Pan Alley (AKA Roughest Place in Town)
# Artist: Stevie Ray Vaughan
# Count: 6
# ('Souled Out On You', 'Robert Finley', 6)
# Title: Souled Out On You
# Artist: Robert Finley
# Count: 6
# ('I Dreamed A Dream', 'Randy Graff', 6)
# Title: I Dreamed A Dream
# Artist: Randy Graff
# Count: 6
#
# [last month greatest hits]
# ("I Don't Want to Set the World on Fire", 'The Ink Spots', 9)
# Title: I Don't Want to Set the World on Fire
# Artist: The Ink Spots
# Count: 9
# ('Bacán tu casa', 'Gepe', 9)
# Title: Bacán tu casa
# Artist: Gepe
# Count: 9
# ('Goodnight My Someone', 'Shirley Jones', 9)
# Title: Goodnight My Someone
# Artist: Shirley Jones
# Count: 9
#
# [today greatest hits]
# [rock]
# ('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 5)
# Title: Tin Pan Alley (AKA Roughest Place in Town)
# Artist: Stevie Ray Vaughan
# Count: 5
# ('While My Guitar Gently Weeps', 'The Beatles', 2)
# Title: While My Guitar Gently Weeps
# Artist: The Beatles
# Count: 2
# ('I Me Mine', 'The Beatles', 1)
# Title: I Me Mine
# Artist: The Beatles
# Count: 1
#
# [today greatest hits]
# [indie]
# ('Colorvision', 'Com Truise', 1)
# Title: Colorvision
# Artist: Com Truise
# Count: 1
# ('Hey Now', 'London Grammar', 1)
# Title: Hey Now
# Artist: London Grammar
# Count: 1
#
# [today greatest hits]
# [seen live]
# ('Little Martha', 'The Allman Brothers Band', 1)
# Title: Little Martha
# Artist: The Allman Brothers Band
# Count: 1
#
# [today greatest hits]
# [alternative]
# ('Beautiful Day', 'Mozez', 1)
# Title: Beautiful Day
# Artist: Mozez
# Count: 1
# ('Hey Now', 'London Grammar', 1)
# Title: Hey Now
# Artist: London Grammar
# Count: 1
#
# [today greatest hits]
# [electronic]
# ('Colorvision', 'Com Truise', 1)
# Title: Colorvision
# Artist: Com Truise
# Count: 1
# ('PH Theme', "Le Peuple de l'Herbe", 1)
# Title: PH Theme
# Artist: Le Peuple de l'Herbe
# Count: 1
# ('Get Lucky (feat. Pharrell Williams)', 'Daft Punk', 1)
# Title: Get Lucky (feat. Pharrell Williams)
# Artist: Daft Punk
# Count: 1
#
# [yesterday greatest hits]
# [rock]
# ('Marian', 'Kowalski', 1)
# Title: Marian
# Artist: Kowalski
# Count: 1
# ('Blackbird', 'Sarah McLachlan', 1)
# Title: Blackbird
# Artist: Sarah McLachlan
# Count: 1
#
# [yesterday greatest hits]
# [indie]
# ('To Love You All Over Again', 'Madeleine Peyroux', 1)
# Title: To Love You All Over Again
# Artist: Madeleine Peyroux
# Count: 1
# ('Instead', 'Madeleine Peyroux', 1)
# Title: Instead
# Artist: Madeleine Peyroux
# Count: 1
# ('Ona Movie', 'Sofa', 1)
# Title: Ona Movie
# Artist: Sofa
# Count: 1
#
# [yesterday greatest hits]
# [seen live]
# Can not reduce() empty RDD
#
# [yesterday greatest hits]
# [alternative]
# Can not reduce() empty RDD
#
# [yesterday greatest hits]
# [electronic]
# ('The Spins', 'Mac Miller', 1)
# Title: The Spins
# Artist: Mac Miller
# Count: 1
#
# [last week greatest hits]
# [rock]
# ('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 6)
# Title: Tin Pan Alley (AKA Roughest Place in Town)
# Artist: Stevie Ray Vaughan
# Count: 6
# ('Everybody Knows This Is Nowhere', 'Neil Young', 5)
# Title: Everybody Knows This Is Nowhere
# Artist: Neil Young
# Count: 5
# ('Blackbird', 'Sarah McLachlan', 5)
# Title: Blackbird
# Artist: Sarah McLachlan
# Count: 5
#
# [last week greatest hits]
# [indie]
# ('Hey Now', 'London Grammar', 3)
# Title: Hey Now
# Artist: London Grammar
# Count: 3
# ('Grizzly Bear', 'Angus & Julia Stone', 2)
# Title: Grizzly Bear
# Artist: Angus & Julia Stone
# Count: 2
# ('Easy on Me', 'Adele', 2)
# Title: Easy on Me
# Artist: Adele
# Count: 2
#
# [last week greatest hits]
# [seen live]
# ('Why Go', 'Pearl Jam', 1)
# Title: Why Go
# Artist: Pearl Jam
# Count: 1
# ('Little Martha', 'The Allman Brothers Band', 1)
# Title: Little Martha
# Artist: The Allman Brothers Band
# Count: 1
# ('Once', 'Pearl Jam', 1)
# Title: Once
# Artist: Pearl Jam
# Count: 1
#
# [last week greatest hits]
# [alternative]
# ('Hey Now', 'London Grammar', 3)
# Title: Hey Now
# Artist: London Grammar
# Count: 3
# ('Grizzly Bear', 'Angus & Julia Stone', 2)
# Title: Grizzly Bear
# Artist: Angus & Julia Stone
# Count: 2
# ('Easy on Me', 'Adele', 2)
# Title: Easy on Me
# Artist: Adele
# Count: 2
#
# [last week greatest hits]
# [electronic]
# ('The Air I Breathe', 'Badmarsh & Shri', 2)
# Title: The Air I Breathe
# Artist: Badmarsh & Shri
# Count: 2
# ('Get Lucky (feat. Pharrell Williams)', 'Daft Punk', 2)
# Title: Get Lucky (feat. Pharrell Williams)
# Artist: Daft Punk
# Count: 2
# ('Raid the Radio', 'General Elektriks', 2)
# Title: Raid the Radio
# Artist: General Elektriks
# Count: 2
#
# [last month greatest hits]
# [rock]
# ('Blackbird', 'Sarah McLachlan', 8)
# Title: Blackbird
# Artist: Sarah McLachlan
# Count: 8
# ('Dani California', 'Red Hot Chili Peppers', 7)
# Title: Dani California
# Artist: Red Hot Chili Peppers
# Count: 7
# ('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 6)
# Title: Tin Pan Alley (AKA Roughest Place in Town)
# Artist: Stevie Ray Vaughan
# Count: 6
#
# [last month greatest hits]
# [indie]
# ('Hey Now', 'London Grammar', 3)
# Title: Hey Now
# Artist: London Grammar
# Count: 3
# ('Small Town', 'Hoodie Allen', 2)
# Title: Small Town
# Artist: Hoodie Allen
# Count: 2
# ('Grizzly Bear', 'Angus & Julia Stone', 2)
# Title: Grizzly Bear
# Artist: Angus & Julia Stone
# Count: 2
#
# [last month greatest hits]
# [seen live]
# ('Charlie', 'Red Hot Chili Peppers', 4)
# Title: Charlie
# Artist: Red Hot Chili Peppers
# Count: 4
# ('Moizefala', 'Los Tres', 4)
# Title: Moizefala
# Artist: Los Tres
# Count: 4
# ('Snow (Hey Oh)', 'Red Hot Chili Peppers', 4)
# Title: Snow (Hey Oh)
# Artist: Red Hot Chili Peppers
# Count: 4
#
# [last month greatest hits]
# [alternative]
# ('Dani California', 'Red Hot Chili Peppers', 7)
# Title: Dani California
# Artist: Red Hot Chili Peppers
# Count: 7
# ('Black Summer', 'Red Hot Chili Peppers', 4)
# Title: Black Summer
# Artist: Red Hot Chili Peppers
# Count: 4
# ('Charlie', 'Red Hot Chili Peppers', 4)
# Title: Charlie
# Artist: Red Hot Chili Peppers
# Count: 4
#
# [last month greatest hits]
# [electronic]
# ('Bacán tu casa', 'Gepe', 9)
# Title: Bacán tu casa
# Artist: Gepe
# Count: 9
# ('The Air I Breathe', 'Badmarsh & Shri', 2)
# Title: The Air I Breathe
# Artist: Badmarsh & Shri
# Count: 2
# ('Get Lucky (feat. Pharrell Williams)', 'Daft Punk', 2)
# Title: Get Lucky (feat. Pharrell Williams)
# Artist: Daft Punk
# Count: 2

# %%
print(all_hits_dict)
print()
print(genre_hits_dict)
# Out:
# {'today': [('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 5), ("Goin' Down South", 'Kenny Brown', 2), ('While My Guitar Gently Weeps', 'The Beatles', 2)], 'yesterday': [('Souled Out On You', 'Robert Finley', 6), ('Make Me Feel Alright', 'Robert Finley', 3), ('Better Than I Treat Myself', 'Robert Finley', 3)], 'last week': [('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 6), ('Souled Out On You', 'Robert Finley', 6), ('I Dreamed A Dream', 'Randy Graff', 6)], 'last month': [("I Don't Want to Set the World on Fire", 'The Ink Spots', 9), ('Bacán tu casa', 'Gepe', 9), ('Goodnight My Someone', 'Shirley Jones', 9)]}
#
# {'today': {'rock': [('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 5), ('While My Guitar Gently Weeps', 'The Beatles', 2), ('I Me Mine', 'The Beatles', 1)], 'indie': [('Colorvision', 'Com Truise', 1), ('Hey Now', 'London Grammar', 1)], 'seen live': [('Little Martha', 'The Allman Brothers Band', 1)], 'alternative': [('Beautiful Day', 'Mozez', 1), ('Hey Now', 'London Grammar', 1)], 'electronic': [('Colorvision', 'Com Truise', 1), ('PH Theme', "Le Peuple de l'Herbe", 1), ('Get Lucky (feat. Pharrell Williams)', 'Daft Punk', 1)]}, 'yesterday': {'rock': [('Marian', 'Kowalski', 1), ('Blackbird', 'Sarah McLachlan', 1)], 'indie': [('To Love You All Over Again', 'Madeleine Peyroux', 1), ('Instead', 'Madeleine Peyroux', 1), ('Ona Movie', 'Sofa', 1)], 'seen live': [], 'alternative': [], 'electronic': [('The Spins', 'Mac Miller', 1)]}, 'last week': {'rock': [('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 6), ('Everybody Knows This Is Nowhere', 'Neil Young', 5), ('Blackbird', 'Sarah McLachlan', 5)], 'indie': [('Hey Now', 'London Grammar', 3), ('Grizzly Bear', 'Angus & Julia Stone', 2), ('Easy on Me', 'Adele', 2)], 'seen live': [('Why Go', 'Pearl Jam', 1), ('Little Martha', 'The Allman Brothers Band', 1), ('Once', 'Pearl Jam', 1)], 'alternative': [('Hey Now', 'London Grammar', 3), ('Grizzly Bear', 'Angus & Julia Stone', 2), ('Easy on Me', 'Adele', 2)], 'electronic': [('The Air I Breathe', 'Badmarsh & Shri', 2), ('Get Lucky (feat. Pharrell Williams)', 'Daft Punk', 2), ('Raid the Radio', 'General Elektriks', 2)]}, 'last month': {'rock': [('Blackbird', 'Sarah McLachlan', 8), ('Dani California', 'Red Hot Chili Peppers', 7), ('Tin Pan Alley (AKA Roughest Place in Town)', 'Stevie Ray Vaughan', 6)], 'indie': [('Hey Now', 'London Grammar', 3), ('Small Town', 'Hoodie Allen', 2), ('Grizzly Bear', 'Angus & Julia Stone', 2)], 'seen live': [('Charlie', 'Red Hot Chili Peppers', 4), ('Moizefala', 'Los Tres', 4), ('Snow (Hey Oh)', 'Red Hot Chili Peppers', 4)], 'alternative': [('Dani California', 'Red Hot Chili Peppers', 7), ('Black Summer', 'Red Hot Chili Peppers', 4), ('Charlie', 'Red Hot Chili Peppers', 4)], 'electronic': [('Bacán tu casa', 'Gepe', 9), ('The Air I Breathe', 'Badmarsh & Shri', 2), ('Get Lucky (feat. Pharrell Williams)', 'Daft Punk', 2)]}}

# %%
storage.write(all_hits_dict, 'all_greatest_hits')
storage.write(genre_hits_dict, 'genre_greatest_hits')
# Out:
# 'https://storage.googleapis.com/a4bd-project-2.appspot.com/genre_greatest_hits'
