# %% [markdown]
# # Set up

# %%
# !git clone https://github.com/aliswh/lastfm
# !cd lastfm; pip install -r requirements.txt
# Out:
# Cloning into 'lastfm'...
# remote: Enumerating objects: 458, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 458 (delta 1), reused 0 (delta 0), pack-reused 456
# Receiving objects: 100% (458/458), 5.02 MiB | 19.11 MiB/s, done.
# Resolving deltas: 100% (287/287), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.18.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (2.23.0)
# Collecting pylast
#   Downloading pylast-5.0.0-py3-none-any.whl (25 kB)
# Collecting pyspark
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 40 kB/s
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->-r requirements.txt (line 1)) (1.0.3)
# Requirement already satisfied: google-auth>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->-r requirements.txt (line 1)) (1.35.0)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage->-r requirements.txt (line 1)) (4.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage->-r requirements.txt (line 1)) (4.2.4)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage->-r requirements.txt (line 1)) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->-r requirements.txt (line 1)) (1.31.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->-r requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->-r requirements.txt (line 1)) (1.56.2)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->-r requirements.txt (line 1)) (3.17.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->-r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->-r requirements.txt (line 2)) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2.0->google-cloud-storage->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from pylast->-r requirements.txt (line 3)) (4.11.4)
# Collecting httpx
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.5 MB/s
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 61.0 MB/s
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 3.2 MB/s
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 4.3 MB/s
# Collecting anyio==3.*
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 11.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from anyio==3.*->httpcore<0.16.0,>=0.15.0->httpx->pylast->-r requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->pylast->-r requirements.txt (line 3)) (3.8.0)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=ba2e23cd8859181cc81660ff8d14579b7f5bb83e24d76b37178be11433fb9061
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# Installing collected packages: sniffio, rfc3986, h11, anyio, httpcore, py4j, httpx, pyspark, pylast
# Successfully installed anyio-3.6.1 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 py4j-0.10.9.3 pylast-5.0.0 pyspark-3.2.1 rfc3986-1.5.0 sniffio-1.2.0

# %%
# !wget https://storage.googleapis.com/hadoop-lib/gcs/gcs-connector-hadoop3-latest.jar
# !cp gcs-connector-hadoop3-latest.jar /usr/local/lib/python3.7/dist-packages/pyspark/jars
# Out:
# --2022-06-08 15:27:13--  https://storage.googleapis.com/hadoop-lib/gcs/gcs-connector-hadoop3-latest.jar
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.45.16, 172.217.12.240, 172.253.62.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.45.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33831577 (32M) [application/java-archive]
# Saving to: ‘gcs-connector-hadoop3-latest.jar’
#
# gcs-connector-hadoo 100%[===================>]  32.26M  --.-KB/s    in 0.1s
#
# 2022-06-08 15:27:14 (277 MB/s) - ‘gcs-connector-hadoop3-latest.jar’ saved [33831577/33831577]

# %%
import json
import datetime

import pyspark
from pyspark.sql import SparkSession
from py4j.java_gateway import UserHelpAutoCompletion
from lastfm.src.ingestion_layer.googlestorage import *
from lastfm.src.ingestion_layer.pylastsource import *
from lastfm.src.ingestion_layer.config import *
from lastfm.src.ingestion_layer.batchwriter import *
from lastfm.src.ingestion_layer.pysparkreader import *

# %% [markdown]
# # PySpark Context onto Google Cloud Storage

# %%
spark = SparkSession.builder.appName('A4BD Project').getOrCreate()
sc = pyspark.SparkContext.getOrCreate()
reader = PySparkReader(sc)
source = PyLastSource(AUTH_DATA) # for tests

# %%
storage = GoogleStorageJSON('./lastfm/src/ingestion_layer/creds.json',BUCKET_NAME)
writer = BatchWriter(source, storage)
# writer.write('test', SEED_USER, 3, 30, debug=True)

# %% [markdown]
# # Read from storage

# %%
recent_tracks_rdd = reader.read('recent_tracks',dir=True)
recent_tracks_rdd.count()
# Out:
# 10

# %%
tracks_rdd = reader.read('tracks',dir=True)
tracks_rdd.count()
# Out:
# 2132

# %%
artists_rdd = reader.read('artists',dir=True)
artists_rdd.count()
# Out:
# 1246

# %% [markdown]
# # User features
#
# 1. Extract listening sessions from users:
#   * list of concatenated songs with a play events +-10 sec after the actual song completed
# 2. Know statistics about these sessions:
#   * average number of tracks
#   * average session per user
#   * session lengths

# %% [markdown]
# ## Extract listening sessions

# %% [markdown]
# Preprocessing

# %%
def to_datetime(x):
  timestamp_date = lambda ts: datetime.fromtimestamp(int(ts))
  date_date = lambda ts: datetime.strptime(ts, '%d %b %Y, %H:%M')
  x[1]['date'] = date_date(x[1]['date'])
  x[1]['timestamp'] = timestamp_date(x[1]['timestamp'])
  return x

sessions = recent_tracks_rdd.map(lambda x: (x['user'], x['recent_tracks'])) \
                            .flatMap(lambda x: map(lambda val: (x[0], val), x[1])) \
                            .map(lambda x: to_datetime(x))
                            
sessions.take(1)
# Out:
# [('kurtphyre',
#   {'album': "She Ain't Here: A Tribute to R.L. Burnside",
#    'artist': 'The Juke Joint Highball',
#    'date': datetime.datetime(2022, 2, 21, 18, 20),
#    'id': '7605616a40ba65675bc43e4c3eb6954eaecfc420',
#    'timestamp': datetime.datetime(2022, 2, 21, 18, 20, 35),
#    'title': "Goin' Down South"})]

# %% [markdown]
# We keep only the `timestamp` because it gives more information w.r.t. `date`, which doesn't include the seconds.
#
# Compute the elapsed time between each song on the sessions as the difference between timestamps (in milliseconds). Keep only the minimal value and the title and artist of the first song: this way, we get the track and the *time it passed from its starting time till the next track*.

# %%
def timestamp_to_delta(ts1, ts2):
  return int((ts2 - ts1).total_seconds() * 1000)

sessions = sessions.join(sessions) \
                   .filter(lambda x: x[1][0]['date'] < x[1][1]['date']) \
                   .map(lambda x: ((x[0], x[1][0]['title'], x[1][0]['artist'], x[1][0]['timestamp']), timestamp_to_delta(x[1][0]['timestamp'], x[1][1]['timestamp']))) \
                   .reduceByKey(lambda x,y: min(x,y))

sessions.take(1)
# Out:
# [(('abernes',
#    'Turandot: Nessun dorma',
#    'Thomas Harper',
#    datetime.datetime(2021, 2, 22, 23, 8, 48)),
#   135000)]

# %%
sessions = sessions.map(lambda x: ((x[0][1], x[0][2]), (x[0][0], x[0][3], x[1])))
sessions.take(1)
# Out:
# [(('Turandot: Nessun dorma', 'Thomas Harper'),
#   ('abernes', datetime.datetime(2021, 2, 22, 23, 8, 48), 135000))]

# %% [markdown]
# Now take the duration of each track to get, in the end, the difference between the elapsed time between two tracks and the duration of the first:
# * if the difference is `0`, it means the track has been played and another track started immediately after
# * if the difference is `< 0`, it means the track has not been played in full
# * if the difference is `> 0`, it means that some time passed after the track has been played in full, before getting to the next song. *This is what we are looking for.* If this value is bigger than some threshold, we consider the session finished.

# %%
tr_rdd = tracks_rdd.map(lambda x: ((x['title'],x['artist']),x['duration']))
tr_rdd.take(10)
# Out:
# [(('Nightlight', 'Illenium'), 222000),
#  (('Let Em Know', "ill' j"), 154000),
#  (('Dlaczego nic', 'IRA'), 237000),
#  (('Lida Rose / Will I Ever Tell You?', 'Shirley Jones'), 256000),
#  (('Mr DG', 'Colman Brothers'), 256000),
#  (('Senbonzakura', 'WagakkiBand'), 0),
#  (('CZY TU JEST NASZ DOM?', 'blurred pink'), 277000),
#  (('Que alegría', 'NVSCVR'), 152000),
#  (('Mobbin', 'Grandtheft'), 186000),
#  (('Ekans', 'Molife'), 141000)]

# %%
sessions_tracks = sessions.join(tr_rdd)\
                          .mapValues(lambda x: (x[0][0], x[0][1], x[1], x[0][2]))
sessions_tracks.take(10) # sx from listening session, dx from track
# Out:
# [(('Elegia', 'New Order'),
#   ('stephiesama', datetime.datetime(2017, 8, 27, 20, 21, 50), 294000, 297000)),
#  (('Te Desheredo', 'Los Tres'),
#   ('Frax777', datetime.datetime(2022, 2, 9, 2, 20, 10), 288000, 207000)),
#  (('Krywaniu', 'Gooral'),
#   ('Gunthar666', datetime.datetime(2022, 2, 11, 9, 46, 24), 240000, 242000)),
#  (('tempo futuro', 'Nicola Conte'),
#   ('jumd', datetime.datetime(2022, 2, 17, 12, 46, 41), 277000, 148000)),
#  (("Don't Matter Now", 'Abby Anderson'),
#   ('abernes', datetime.datetime(2021, 2, 1, 5, 26, 24), 223000, 159000)),
#  (('solo', 'Nicola Conte'),
#   ('jumd', datetime.datetime(2022, 2, 16, 18, 27, 8), 147000, 147000)),
#  (('Gospel (with Eminem)', 'Dr. Dre'),
#   ('Gunthar666', datetime.datetime(2022, 2, 15, 11, 36, 46), 0, 211000)),
#  (('Gospel (with Eminem)', 'Dr. Dre'),
#   ('Gunthar666', datetime.datetime(2022, 2, 13, 7, 43, 53), 0, 211000)),
#  (('Wild', 'Missy Lancaster'),
#   ('abernes', datetime.datetime(2021, 2, 1, 6, 11, 12), 208000, 218000)),
#  (("Tarantino's Tango", 'Gare du Nord'),
#   ('jumd', datetime.datetime(2022, 2, 18, 15, 43, 59), 192000, 193000))]

# %%
tr_rdd.filter(lambda x: x[1] == 0).take(3)
# Out:
# [(('Senbonzakura', 'WagakkiBand'), 0),
#  (('Chopin: Piano Concerto No. 2 in F Minor, Op. 21 - III. Allegro vivace',
#    'Benjamin Grosvenor, Royal Scottish National Orchestra, Elim Chan'),
#   0),
#  (('Often', 'Adas'), 0)]

# %% [markdown]
# **Problem**: missing duration for some tracks
#
# **Fix**: take max duration from the tracks by that artist in the listening session to fill missing values.
#
# This could still produce some imprecision, but we need to put a patch.

# %%
artist_max = sessions_tracks.map(lambda x: (x[0][1], x[1][2])) \
                            .reduceByKey(lambda x,y: max(x,y))
artist_max.take(10)
# Out:
# [('Volbeat', 374000),
#  ('Carpenter Brut', 403000),
#  ('The Hellacopters', 0),
#  ('senio', 214000),
#  ('Pedropiedra', 232000),
#  ('Brandon Ray', 186000),
#  ('Tommy Guerrero & Gadget', 207000),
#  ('Bethel', 217000),
#  ('Alice et Moi', 0),
#  ('Anne-Sophie Mutter, Yo-Yo Ma, Daniel Barenboim, West-Eastern Divan Orchestra',
#   316000)]

# %% [markdown]
# Some artist still don't have a duration value, but if they don't have it in the recent tracks, maybe they have in their top tracks!
#
# This could still not work, so we put a default value, like the average of all values for the tracks listened by that user in the recent tracks, because we presume that a user usually listens to songs of similar length.

# %%
artist_avg = artist_max.filter(lambda x: x[1] != 0).map(lambda x: (x[1],1)).reduce(lambda x,y: ((x[0]+y[0]),(x[1]+y[1])) )
artist_avg = artist_avg[0] // artist_avg[1]
artist_avg
# Out:
# 248854

# %%
artist_max = artists_rdd.map(lambda x: (x['artist'], max([int(track['duration']) for track in x['top_tracks'] ]) )) \
                        .join(artist_max) \
                        .mapValues(lambda x: x[1] if x[1] != 0 else artist_avg)
artist_max.take(10)
# Out:
# [('Gianluca', 190000),
#  ('Elöhim', 248854),
#  ('Tim McGraw, Tyler Hubbard', 176000),
#  ('Kamil Kowalski', 253000),
#  ('Stevie Ray Vaughan and Double Trouble', 199000),
#  ('DJ Antoine', 248854),
#  ('Kid Francescoli', 391000),
#  ('Stubby Kaye', 135000),
#  ('Jerome The Prince', 150000),
#  ('Snavs', 195000)]

# %% [markdown]
# Now merge duration per track in `tr_rdd`.

# %%
fixed_tr_rdd = tr_rdd.map(lambda x: (x[0][1], (x[0][0], x[1]))) \
                     .join(artist_max) \
                     .map(lambda x: ((x[1][0][0],x[0]), (x[1][0][1], x[1][1]))) 
fixed_tr_rdd.take(10)
# Out:
# [(('La tête dans les étoiles', 'Doctor Flake'), (257000, 257000)),
#  (('Feeling Better', 'Gabriel Vitel'), (380000, 380000)),
#  (('Feeling Better - Radio Version', 'Gabriel Vitel'), (0, 380000)),
#  (("Don't Stop", 'Going Deeper'), (165000, 165000)),
#  (('With the Moon Behind', 'Sleepy Clouds'), (213000, 213000)),
#  (('Hear My Call (feat. Tyler Graves)', 'Trivecta'), (0, 248854)),
#  (('Symphony No. 5: IV. Adagietto: Sehr langsam',
#    'Polish National Radio Symphony Orchestra'),
#   (0, 248854)),
#  (('Two Hundred Grand', 'Sunshine'), (255000, 255000)),
#  (('Always', 'Gary McPhail'), (0, 248854)),
#  (('Levi Denim', 'Chase Martin'), (151000, 151000))]

# %%
fixed_tr_rdd = fixed_tr_rdd.mapValues(lambda x: x[0] if x[0] != 0 else x[1])
fixed_tr_rdd.take(10)
# Out:
# [(('La tête dans les étoiles', 'Doctor Flake'), 257000),
#  (('Feeling Better', 'Gabriel Vitel'), 380000),
#  (('Feeling Better - Radio Version', 'Gabriel Vitel'), 380000),
#  (("Don't Stop", 'Going Deeper'), 165000),
#  (('With the Moon Behind', 'Sleepy Clouds'), 213000),
#  (('Hear My Call (feat. Tyler Graves)', 'Trivecta'), 248854),
#  (('Symphony No. 5: IV. Adagietto: Sehr langsam',
#    'Polish National Radio Symphony Orchestra'),
#   248854),
#  (('Two Hundred Grand', 'Sunshine'), 255000),
#  (('Always', 'Gary McPhail'), 248854),
#  (('Levi Denim', 'Chase Martin'), 151000)]

# %% [markdown]
# Finally compute the listening sessions.

# %%
sessions_tracks = sessions.join(fixed_tr_rdd)\
                          .mapValues(lambda x: (x[0][0], x[0][1], x[1], x[0][2]))
sessions_tracks.take(10) # sx from listening session, dx from track
# Out:
# [(('Silence (Feat. Sarah McLachlan) [Alyx Ander vs. Delerium] [Radio Edit]',
#    'Delerium'),
#   ('23kulpamens', datetime.datetime(2020, 1, 27, 9, 23, 13), 219000, 203000)),
#  (('Silence (Feat. Sarah McLachlan) [Alyx Ander vs. Delerium] [Radio Edit]',
#    'Delerium'),
#   ('23kulpamens', datetime.datetime(2020, 1, 25, 9, 47, 5), 219000, 399000)),
#  (('Silence (Feat. Sarah McLachlan) [Alyx Ander vs. Delerium] [Radio Edit]',
#    'Delerium'),
#   ('23kulpamens', datetime.datetime(2020, 1, 25, 9, 46, 32), 219000, 33000)),
#  (('Vertical', 'Adrian Stresow'),
#   ('junjindua', datetime.datetime(2022, 2, 14, 16, 23, 39), 192000, 194000)),
#  (('Vertical', 'Adrian Stresow'),
#   ('junjindua', datetime.datetime(2022, 2, 17, 11, 38, 55), 192000, 194000)),
#  (('Vertical', 'Adrian Stresow'),
#   ('junjindua', datetime.datetime(2022, 2, 17, 11, 42, 9), 192000, 192000)),
#  (('Vertical', 'Adrian Stresow'),
#   ('junjindua', datetime.datetime(2022, 2, 13, 17, 50, 10), 192000, 193000)),
#  (('Vertical', 'Adrian Stresow'),
#   ('junjindua', datetime.datetime(2022, 2, 16, 7, 55), 192000, 194000)),
#  (('Downgrade Desert', 'Igorrr'),
#   ('stephiesama', datetime.datetime(2022, 2, 19, 22, 54, 51), 263000, 588000)),
#  (('Przesilenie', 'Muchy'),
#   ('Gunthar666', datetime.datetime(2022, 2, 12, 20, 46, 59), 214000, 216000))]

# %%
to_min = lambda x: divmod(x//1000, 60)
to_date_string = lambda x: x.strftime("%Y-%m-%d, %H:%M:%S")

sessions_tracks = sessions_tracks.mapValues(lambda x: (x[0], (x[2]-x[3])//1000, to_min(x[2]), to_date_string(x[1]))) \
                                 .groupBy(lambda x: x[1][0]) \
                                 .map(lambda x : (x[0], list(x[1])))
sessions_tracks.take(1)
# Out:
# [('Frax777',
#   [(('Stadium Arcadium', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (5, 15), '2022-02-09, 22:29:34')),
#    (('Dilo', 'Bronko Yotte'),
#     ('Frax777', -597, (4, 24), '2022-02-11, 00:17:25')),
#    (('Dilo', 'Bronko Yotte'), ('Frax777', 0, (4, 24), '2022-02-11, 00:13:00')),
#    (('OK', 'Bronko Yotte'), ('Frax777', 60, (3, 38), '2022-02-11, 00:03:51')),
#    (('OK', 'Bronko Yotte'), ('Frax777', -1, (3, 38), '2022-02-11, 00:00:11')),
#    (('Este Año No Hay Cosecha', 'Pikette23'),
#     ('Frax777', 0, (2, 50), '2022-02-04, 00:04:51')),
#    (('Este Año No Hay Cosecha', 'Pikette23'),
#     ('Frax777', -7, (2, 50), '2022-02-09, 23:18:23')),
#    (('Este Año No Hay Cosecha', 'Pikette23'),
#     ('Frax777', -59, (2, 50), '2022-02-04, 00:07:41')),
#    (('Spoiler', 'Diego Lorenzini'),
#     ('Frax777', 1, (3, 21), '2022-02-10, 14:06:51')),
#    (('Spoiler', 'Diego Lorenzini'),
#     ('Frax777', 0, (3, 21), '2022-02-10, 13:33:25')),
#    (('Dejando Libre el Amor', 'Chancho En Piedra'),
#     ('Frax777', -1, (4, 22), '2022-02-08, 16:30:31')),
#    (('Sombras Chinescas', 'Tiro De Gracia'),
#     ('Frax777', -81, (3, 53), '2022-02-10, 13:28:11')),
#    (('Valparaisito', 'Diego Lorenzini'),
#     ('Frax777', -11845, (0, 32), '2022-02-10, 14:21:23')),
#    (('Ser Amigos', 'Gepe'), ('Frax777', 1, (3, 26), '2022-02-05, 19:54:59')),
#    (('Yavida', 'Cultura Profética'),
#     ('Frax777', 75, (4, 8), '2022-02-04, 00:36:30')),
#    (('Yavida', 'Cultura Profética'),
#     ('Frax777', -13, (4, 8), '2022-02-04, 00:32:09')),
#    (('Yavida', 'Cultura Profética'),
#     ('Frax777', -13, (4, 8), '2022-02-09, 23:44:42')),
#    (('Enter Sandman', 'Metallica'),
#     ('Frax777', -1226, (6, 33), '2022-02-07, 22:06:28')),
#    (('Enter Sandman', 'Metallica'),
#     ('Frax777', 62, (6, 33), '2022-02-07, 21:22:45')),
#    (('For Whom The Bell Tolls - Remastered', 'Metallica'),
#     ('Frax777', 61, (5, 9), '2022-02-07, 22:02:20')),
#    (('Revolución en Estéreo', 'Cultura Profética'),
#     ('Frax777', -89, (4, 8), '2022-02-04, 00:14:07')),
#    (('Revolución en Estéreo', 'Cultura Profética'),
#     ('Frax777', -88, (4, 8), '2022-02-09, 23:23:48')),
#    (('Revolución en Estéreo', 'Cultura Profética'),
#     ('Frax777', 22, (4, 8), '2022-02-04, 00:19:44')),
#    (('Slow Cheetah', 'Red Hot Chili Peppers'),
#     ('Frax777', -9, (5, 20), '2022-02-07, 23:52:34')),
#    (('Slow Cheetah', 'Red Hot Chili Peppers'),
#     ('Frax777', -23, (5, 20), '2022-02-09, 22:41:48')),
#    (('All The Way Up', 'Fat Joe'),
#     ('Frax777', -10381, (3, 11), '2022-02-09, 19:26:52')),
#    (('Cuando quieras', 'Guachupé'),
#     ('Frax777', -22238, (3, 53), '2022-02-08, 17:17:02')),
#    (('Amar en el campo', 'Teleradio Donoso'),
#     ('Frax777', -1, (3, 57), '2022-02-08, 16:54:03')),
#    (('Snow (Hey Oh)', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (5, 34), '2022-02-06, 21:21:16')),
#    (('Snow (Hey Oh)', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (5, 34), '2022-02-07, 23:32:53')),
#    (('Snow (Hey Oh)', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (5, 34), '2022-02-05, 20:06:13')),
#    (('Snow (Hey Oh)', 'Red Hot Chili Peppers'),
#     ('Frax777', -39667, (5, 34), '2022-02-09, 02:42:00')),
#    (('Dani California', 'Red Hot Chili Peppers'),
#     ('Frax777', -5, (4, 43), '2022-02-07, 23:28:05')),
#    (('Dani California', 'Red Hot Chili Peppers'),
#     ('Frax777', -652, (4, 43), '2022-02-06, 00:58:02')),
#    (('Dani California', 'Red Hot Chili Peppers'),
#     ('Frax777', 6, (4, 43), '2022-02-10, 18:00:35')),
#    (('Dani California', 'Red Hot Chili Peppers'),
#     ('Frax777', 1, (4, 43), '2022-02-10, 17:55:53')),
#    (('Dani California', 'Red Hot Chili Peppers'),
#     ('Frax777', -820, (4, 43), '2022-02-09, 02:23:37')),
#    (('Dani California', 'Red Hot Chili Peppers'),
#     ('Frax777', 2, (4, 43), '2022-02-06, 21:16:35')),
#    (('Dani California', 'Red Hot Chili Peppers'),
#     ('Frax777', 2, (4, 43), '2022-02-05, 20:01:32')),
#    (('Warlocks', 'Red Hot Chili Peppers'),
#     ('Frax777', -6, (3, 25), '2022-02-08, 00:06:22')),
#    (('Me voy a Valparaíso', 'Diego Lorenzini'),
#     ('Frax777', 13, (4, 32), '2022-02-10, 14:02:32')),
#    (('Ay Dios Mio', 'DavUS'),
#     ('Frax777', -81, (2, 28), '2022-02-04, 00:07:41')),
#    (('Ay Dios Mio', 'DavUS'), ('Frax777', 0, (2, 28), '2022-02-09, 23:21:20')),
#    (('XANDER FREESTYLE', 'Gianluca'),
#     ('Frax777', -46702, (1, 43), '2022-02-10, 00:12:24')),
#    (('THATS WHAT I WANT', 'Lil Nas X'),
#     ('Frax777', 62, (3, 32), '2022-02-09, 23:13:15')),
#    (('flowers', 'In Love With a Ghost'),
#     ('Frax777', -5011, (4, 12), '2022-02-10, 21:52:40')),
#    (('flowers', 'In Love With a Ghost'),
#     ('Frax777', -575, (4, 12), '2022-02-10, 21:38:53')),
#    (('flowers', 'In Love With a Ghost'),
#     ('Frax777', 176, (4, 12), '2022-02-10, 23:20:23')),
#    (('Wet Sand', 'Red Hot Chili Peppers'),
#     ('Frax777', 64, (5, 9), '2022-02-10, 18:23:53')),
#    (('Wet Sand', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (5, 9), '2022-02-10, 18:18:43')),
#    (('Wet Sand', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (5, 9), '2022-02-08, 00:09:53')),
#    (('Un Gran Vacío', 'Gepe'),
#     ('Frax777', -10941, (6, 1), '2022-02-04, 13:52:23')),
#    (('She Looks to Me', 'Red Hot Chili Peppers'),
#     ('Frax777', 1, (4, 6), '2022-02-08, 13:07:40')),
#    (('Alturas', 'Inti-Illimani'),
#     ('Frax777', 0, (3, 10), '2022-02-08, 16:39:31')),
#    (('Lluvia diente lluvia', 'Gepe'),
#     ('Frax777', -1, (1, 39), '2022-02-04, 13:40:12')),
#    (('God is a woman', 'Ariana Grande'),
#     ('Frax777', 29, (3, 47), '2022-02-04, 00:01:33')),
#    (('Puchero', 'Bronko Yotte'),
#     ('Frax777', -92, (2, 29), '2022-02-10, 23:28:00')),
#    (('Puchero', 'Bronko Yotte'),
#     ('Frax777', 0, (2, 29), '2022-02-10, 23:25:30')),
#    (('Puchero', 'Bronko Yotte'),
#     ('Frax777', -93, (2, 29), '2022-02-11, 16:34:48')),
#    (('Nuestra Fiesta (okupa, segura y no molesta)', 'Tiro De Gracia'),
#     ('Frax777', -1, (2, 7), '2022-02-08, 17:01:54')),
#    (('Nuestra Fiesta (okupa, segura y no molesta)', 'Tiro De Gracia'),
#     ('Frax777', 5, (2, 7), '2022-02-10, 13:21:28')),
#    (('Si bien', 'Bronko Yotte'),
#     ('Frax777', -456, (4, 9), '2022-02-10, 23:32:01')),
#    (('Si bien', 'Bronko Yotte'),
#     ('Frax777', 42, (4, 9), '2022-02-10, 23:43:47')),
#    (('Si bien', 'Bronko Yotte'),
#     ('Frax777', 160, (4, 9), '2022-02-11, 16:42:59')),
#    (('imagino', 'Hordatoj'), ('Frax777', -1, (3, 55), '2022-02-09, 00:26:30')),
#    (('Bailar y Llorar', 'Teleradio Donoso'),
#     ('Frax777', 0, (3, 49), '2022-02-08, 23:37:35')),
#    (('Parte 2', 'Pikette23'),
#     ('Frax777', 14, (3, 46), '2022-02-09, 14:25:51')),
#    (('Parte 2', 'Pikette23'),
#     ('Frax777', -132, (3, 46), '2022-02-09, 13:48:41')),
#    (('La Medicina', 'Los Tetas'),
#     ('Frax777', -36, (4, 0), '2022-02-09, 00:16:32')),
#    (('Vacaciones en el más allá', 'Pedropiedra'),
#     ('Frax777', -1, (3, 52), '2022-02-08, 16:58:01')),
#    (('Mi Coraozn', 'Pikette23'),
#     ('Frax777', 0, (3, 46), '2022-02-04, 00:19:44')),
#    (('Mi Coraozn', 'Pikette23'),
#     ('Frax777', -87, (3, 46), '2022-02-04, 00:23:30')),
#    (('Mi Coraozn', 'Pikette23'),
#     ('Frax777', 0, (3, 46), '2022-02-09, 23:29:24')),
#    (('Mi Coraozn', 'Pikette23'),
#     ('Frax777', -77, (3, 46), '2022-02-09, 14:13:04')),
#    (('Campos Magnéticos', 'Gepe'),
#     ('Frax777', -3, (3, 37), '2022-02-09, 22:54:52')),
#    (('Campos Magnéticos', 'Gepe'),
#     ('Frax777', -8, (3, 37), '2022-02-05, 19:35:59')),
#    (('Campos Magnéticos', 'Gepe'),
#     ('Frax777', 63, (3, 37), '2022-02-10, 18:27:58')),
#    (('Campos Magnéticos', 'Gepe'),
#     ('Frax777', -1, (3, 37), '2022-02-04, 13:36:34')),
#    (('Campos Magnéticos', 'Gepe'),
#     ('Frax777', -28, (3, 37), '2022-02-10, 18:23:53')),
#    (('Abajo', 'Bronko Yotte'),
#     ('Frax777', -34, (2, 50), '2022-02-10, 23:53:12')),
#    (('Abajo', 'Bronko Yotte'),
#     ('Frax777', -1, (2, 50), '2022-02-10, 23:50:21')),
#    (('Amor Enfermizo', 'Tiro De Gracia'),
#     ('Frax777', -1, (2, 20), '2022-02-08, 23:31:33')),
#    (('Pony', 'Diego Lorenzini'),
#     ('Frax777', 0, (3, 28), '2022-02-10, 14:17:55')),
#    (('Use Your Body', 'Dreya Mac'),
#     ('Frax777', -845, (2, 59), '2022-02-04, 00:53:24')),
#    (('Use Your Body', 'Dreya Mac'),
#     ('Frax777', -1, (2, 59), '2022-02-04, 01:29:15')),
#    (('Use Your Body', 'Dreya Mac'),
#     ('Frax777', -35124, (2, 59), '2022-02-04, 01:32:15')),
#    (('Van Damme / Grupo aparte', 'Bronko Yotte'),
#     ('Frax777', -179, (2, 38), '2022-02-04, 00:14:07')),
#    (('Van Damme / Grupo aparte', 'Bronko Yotte'),
#     ('Frax777', 1, (2, 38), '2022-02-04, 00:11:30')),
#    (('Van Damme / Grupo aparte', 'Bronko Yotte'),
#     ('Frax777', -1, (2, 38), '2022-02-11, 00:03:50')),
#    (('Van Damme / Grupo aparte', 'Bronko Yotte'),
#     ('Frax777', 0, (2, 38), '2022-02-09, 23:15:45')),
#    (('Van Damme / Grupo aparte', 'Bronko Yotte'),
#     ('Frax777', -33, (2, 38), '2022-02-11, 00:06:29')),
#    (('Pedro Pesado', 'Tiro De Gracia'),
#     ('Frax777', 0, (3, 0), '2022-02-08, 16:21:56')),
#    (('Gone', 'Jorja Smith'), ('Frax777', 0, (3, 15), '2022-02-04, 13:25:07')),
#    (('Gone', 'Jorja Smith'),
#     ('Frax777', -88, (3, 15), '2022-02-04, 13:28:22')),
#    (('Gone', 'Jorja Smith'),
#     ('Frax777', -2174, (3, 15), '2022-02-07, 22:42:08')),
#    (('Era de verdad', 'Hordatoj'),
#     ('Frax777', -2, (2, 49), '2022-02-08, 23:41:24')),
#    (('Bailar bien, bailar mal', 'Gepe'),
#     ('Frax777', -7865, (3, 45), '2022-02-10, 18:49:30')),
#    (('Bailar bien, bailar mal', 'Gepe'),
#     ('Frax777', 0, (3, 45), '2022-02-09, 22:58:32')),
#    (('Bailar bien, bailar mal', 'Gepe'),
#     ('Frax777', 0, (3, 45), '2022-02-04, 13:41:52')),
#    (('Bailar bien, bailar mal', 'Gepe'),
#     ('Frax777', 29, (3, 45), '2022-02-10, 21:04:20')),
#    (('Bailar bien, bailar mal', 'Gepe'),
#     ('Frax777', -463, (3, 45), '2022-02-10, 18:38:02')),
#    (('Hard to Concentrate', 'Red Hot Chili Peppers'),
#     ('Frax777', -44962, (4, 2), '2022-02-08, 00:29:52')),
#    (('Mi Mejor Momento', 'Chancho En Piedra'),
#     ('Frax777', 1, (3, 23), '2022-02-08, 16:50:41')),
#    (('invierno', 'Gianluca'),
#     ('Frax777', -171, (2, 12), '2022-02-10, 21:09:49')),
#    (('invierno', 'Gianluca'),
#     ('Frax777', -1, (2, 12), '2022-02-10, 21:07:36')),
#    (('Incertidumbre', 'Pikette23'),
#     ('Frax777', 63, (3, 46), '2022-02-09, 14:29:23')),
#    (('Incertidumbre', 'Pikette23'),
#     ('Frax777', 71, (3, 46), '2022-02-09, 13:54:39')),
#    (('Las horas', 'Bronko Yotte'),
#     ('Frax777', -1, (3, 19), '2022-02-11, 00:09:40')),
#    (('Las horas', 'Bronko Yotte'),
#     ('Frax777', -65, (3, 19), '2022-02-11, 00:13:00')),
#    (('Counter Strike', 'DavUS'),
#     ('Frax777', 159, (3, 1), '2022-02-10, 21:20:58')),
#    (('Counter Strike', 'DavUS'),
#     ('Frax777', 4, (3, 1), '2022-02-10, 21:18:01')),
#    (('Matanga', 'Bronko Yotte'),
#     ('Frax777', -9, (3, 11), '2022-02-11, 00:09:40')),
#    (('Matanga', 'Bronko Yotte'),
#     ('Frax777', 0, (3, 11), '2022-02-11, 00:06:29')),
#    (("What's Luv? (Feat. Ja-Rule & Ashanti)", 'Fat Joe'),
#     ('Frax777', -1, (4, 27), '2022-02-09, 19:19:55')),
#    (('Tú Me Dejaste De Querer', 'C. Tangana'),
#     ('Frax777', -24, (3, 18), '2022-02-04, 01:10:28')),
#    (('Del Tope al Fondo', 'Cultura Profética'),
#     ('Frax777', -60, (4, 8), '2022-02-10, 00:07:16')),
#    (('Cienfuegos', 'Bronko Yotte'),
#     ('Frax777', -4, (3, 34), '2022-02-11, 00:00:12')),
#    (('Cienfuegos', 'Bronko Yotte'),
#     ('Frax777', -1, (3, 34), '2022-02-10, 23:56:36')),
#    (('One', 'Metallica'), ('Frax777', -4, (7, 24), '2022-02-07, 21:54:52')),
#    (('Moizefala', 'Los Tres'),
#     ('Frax777', -1, (4, 36), '2022-02-04, 01:21:45')),
#    (('Moizefala', 'Los Tres'),
#     ('Frax777', -1, (4, 36), '2022-02-08, 16:34:54')),
#    (('Moizefala', 'Los Tres'),
#     ('Frax777', -1, (4, 36), '2022-02-10, 18:00:35')),
#    (('Moizefala', 'Los Tres'),
#     ('Frax777', 47, (4, 36), '2022-02-10, 18:05:12')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', -1, (4, 19), '2022-02-10, 17:51:33')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', 2, (4, 19), '2022-02-04, 13:28:48')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', -24802, (4, 19), '2022-02-05, 12:30:31')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', -23, (4, 19), '2022-02-10, 17:55:53')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', 52, (4, 19), '2022-02-05, 19:44:01')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', -182, (4, 19), '2022-02-09, 22:47:31')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', 30, (4, 19), '2022-02-04, 01:14:10')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', -16, (4, 19), '2022-02-10, 13:12:29')),
#    (('Bacán tu casa', 'Gepe'),
#     ('Frax777', 1, (4, 19), '2022-02-05, 19:28:12')),
#    (('Sueños', 'Tiro De Gracia'),
#     ('Frax777', -1, (5, 21), '2022-02-09, 00:21:08')),
#    (('Hey', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (5, 39), '2022-02-08, 00:15:02')),
#    (('Platina', 'Gepe'), ('Frax777', -45, (3, 39), '2022-02-10, 13:17:04')),
#    (('Platina', 'Gepe'), ('Frax777', -38, (3, 39), '2022-02-05, 19:39:44')),
#    (('Platina', 'Gepe'), ('Frax777', -35, (3, 39), '2022-02-09, 23:02:17')),
#    (('Platina', 'Gepe'), ('Frax777', 0, (3, 39), '2022-02-10, 18:09:01')),
#    (('Platina', 'Gepe'), ('Frax777', 1, (3, 39), '2022-02-05, 19:47:28')),
#    (('Platina', 'Gepe'), ('Frax777', 65, (3, 39), '2022-02-10, 18:12:40')),
#    (('Platina', 'Gepe'), ('Frax777', -1, (3, 39), '2022-02-04, 13:45:37')),
#    (('Platina', 'Gepe'), ('Frax777', 33, (3, 39), '2022-02-04, 13:49:17')),
#    (('Extraordinario', 'Pikette23'),
#     ('Frax777', -1, (3, 46), '2022-02-09, 14:09:17')),
#    (('Carnavalito del ciempiés', 'Nano Stern'),
#     ('Frax777', -411, (4, 8), '2022-02-09, 00:05:33')),
#    (('Especially in Michigan', 'Red Hot Chili Peppers'),
#     ('Frax777', 10, (4, 1), '2022-02-09, 14:22:00')),
#    (('Especially in Michigan', 'Red Hot Chili Peppers'),
#     ('Frax777', 2, (4, 1), '2022-02-07, 22:35:38')),
#    (('Especially in Michigan', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (4, 1), '2022-02-08, 00:02:21')),
#    (('Californication', 'Red Hot Chili Peppers'),
#     ('Frax777', -71627, (5, 21), '2022-02-06, 01:13:37')),
#    (('Californication', 'Red Hot Chili Peppers'),
#     ('Frax777', -69865, (5, 21), '2022-02-04, 17:00:45')),
#    (('Need to Know', 'Doja Cat'),
#     ('Frax777', 5, (3, 36), '2022-02-10, 17:45:05')),
#    (('Need to Know', 'Doja Cat'),
#     ('Frax777', 39, (3, 36), '2022-02-10, 17:48:36')),
#    (('Lo Que Ven Mis Ojos', 'Tiro De Gracia'),
#     ('Frax777', -2, (3, 40), '2022-02-08, 16:24:56')),
#    (('BANANA', 'Gianluca'), ('Frax777', -2, (3, 10), '2022-02-09, 23:56:23')),
#    (('BANANA', 'Gianluca'), ('Frax777', -2, (3, 10), '2022-02-04, 00:39:23')),
#    (('Corsario Universal', 'Tiro De Gracia'),
#     ('Frax777', -55, (3, 46), '2022-02-10, 13:23:30')),
#    (('Corsario Universal', 'Tiro De Gracia'),
#     ('Frax777', -4, (3, 46), '2022-02-08, 23:46:37')),
#    (('Chao Mi Niño', 'Diego Lorenzini'),
#     ('Frax777', -1082, (2, 13), '2022-02-10, 13:42:17')),
#    (('Chao Mi Niño', 'Diego Lorenzini'),
#     ('Frax777', -1, (2, 13), '2022-02-10, 14:15:41')),
#    (('Master of Puppets', 'Metallica'),
#     ('Frax777', -1, (8, 35), '2022-02-07, 21:34:44')),
#    (('Fade', 'Kanye West'), ('Frax777', 85, (3, 13), '2022-02-10, 21:29:22')),
#    (('Charlie', 'Red Hot Chili Peppers'),
#     ('Frax777', -153, (4, 37), '2022-02-07, 23:38:27')),
#    (('Charlie', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (4, 37), '2022-02-09, 22:24:57')),
#    (('Charlie', 'Red Hot Chili Peppers'),
#     ('Frax777', -18372, (4, 37), '2022-02-06, 21:26:51')),
#    (('Charlie', 'Red Hot Chili Peppers'),
#     ('Frax777', -16897, (4, 37), '2022-02-05, 20:11:48')),
#    (('Libre', 'Gepe'), ('Frax777', -1, (3, 28), '2022-02-04, 13:33:05')),
#    (('Libre', 'Gepe'), ('Frax777', -1, (3, 28), '2022-02-05, 19:32:30')),
#    (('Ateo', 'C. Tangana'), ('Frax777', -1, (3, 59), '2022-02-09, 23:06:31')),
#    (('Ateo', 'C. Tangana'), ('Frax777', 41, (3, 59), '2022-02-04, 00:01:33')),
#    (('Ateo', 'C. Tangana'), ('Frax777', -2, (3, 59), '2022-02-03, 23:57:32')),
#    (('TDG Crew', 'Tiro De Gracia'),
#     ('Frax777', 0, (3, 39), '2022-02-08, 16:18:17')),
#    (('TDG Crew', 'Tiro De Gracia'),
#     ('Frax777', -22, (3, 39), '2022-02-08, 16:46:40')),
#    (('Salmo', 'Bronko Yotte'),
#     ('Frax777', -1, (3, 25), '2022-02-04, 00:28:43')),
#    (('Salmo', 'Bronko Yotte'),
#     ('Frax777', -1, (3, 25), '2022-02-09, 23:41:16')),
#    (('Salmo', 'Bronko Yotte'),
#     ('Frax777', -56, (3, 25), '2022-02-04, 00:32:09')),
#    (('Universally Speaking', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (4, 17), '2022-02-04, 00:45:29')),
#    (('Universally Speaking', 'Red Hot Chili Peppers'),
#     ('Frax777', -10, (4, 17), '2022-02-09, 23:49:03')),
#    (('Endorfinas', 'Bronko Yotte'),
#     ('Frax777', 83, (3, 52), '2022-02-11, 16:32:19')),
#    (('Endorfinas', 'Bronko Yotte'),
#     ('Frax777', -8, (3, 52), '2022-02-10, 21:34:53')),
#    (('Endorfinas', 'Bronko Yotte'),
#     ('Frax777', -595, (3, 52), '2022-02-10, 21:38:53')),
#    (('Bomba Chaya', 'Gepe'), ('Frax777', -46, (3, 7), '2022-02-05, 19:51:06')),
#    (('Bomba Chaya', 'Gepe'), ('Frax777', 1, (3, 7), '2022-02-04, 13:49:17')),
#    (('Dark Necessities', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (5, 2), '2022-02-10, 21:09:49')),
#    (('Dark Necessities', 'Red Hot Chili Peppers'),
#     ('Frax777', 113, (5, 2), '2022-02-10, 21:14:52')),
#    (('Caught Their Eyes', 'JAY-Z'),
#     ('Frax777', 42, (4, 8), '2022-02-10, 21:25:56')),
#    (('Caught Their Eyes', 'JAY-Z'),
#     ('Frax777', 140, (4, 8), '2022-02-10, 21:29:22')),
#    (('La Espada & la Pared', 'Los Tres'),
#     ('Frax777', 232, (8, 55), '2022-02-09, 02:05:57')),
#    (('iced tea for breakfast', 'In Love With a Ghost'),
#     ('Frax777', 0, (1, 16), '2022-02-10, 23:20:23')),
#    (('iced tea for breakfast', 'In Love With a Ghost'),
#     ('Frax777', -155, (1, 16), '2022-02-10, 23:21:39')),
#    (('Desecration Smile', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (5, 2), '2022-02-08, 00:20:42')),
#    (('Felipe Camiroaga', 'Diego Lorenzini'),
#     ('Frax777', -11572, (4, 32), '2022-02-10, 14:21:56')),
#    (('Al Capone', 'Bronko Yotte'),
#     ('Frax777', -464, (4, 1), '2022-02-10, 23:32:01')),
#    (('Al Capone', 'Bronko Yotte'),
#     ('Frax777', 240, (4, 1), '2022-02-10, 23:27:59')),
#    (('Al Capone', 'Bronko Yotte'),
#     ('Frax777', -8, (4, 1), '2022-02-11, 16:38:50')),
#    (('Born Sinner', 'Lecrae'),
#     ('Frax777', -23, (2, 12), '2022-02-10, 21:31:10')),
#    (('Born Sinner', 'Lecrae'),
#     ('Frax777', 64, (2, 12), '2022-02-10, 21:33:45')),
#    (('Galactica', 'Pikette23'),
#     ('Frax777', 92, (3, 46), '2022-02-09, 13:57:14')),
#    (('Galactica', 'Pikette23'),
#     ('Frax777', 92, (3, 46), '2022-02-09, 14:34:41')),
#    (('Sunshine (The Light)', 'Fat Joe'),
#     ('Frax777', 0, (2, 29), '2022-02-09, 19:24:23')),
#    (('Mataz', 'Lucybell'), ('Frax777', -72, (5, 49), '2022-02-08, 23:58:32')),
#    (('Cerrar y Abrir', 'Los Tres'),
#     ('Frax777', -1, (4, 14), '2022-02-08, 17:12:47')),
#    (('Readymade', 'Red Hot Chili Peppers'),
#     ('Frax777', -100, (4, 30), '2022-02-08, 13:11:45')),
#    (('Ser hümano', 'Tiro De Gracia'),
#     ('Frax777', 208, (5, 21), '2022-02-08, 16:28:38')),
#    (("She's Only 18", 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (3, 25), '2022-02-09, 22:38:22')),
#    (("She's Only 18", 'Red Hot Chili Peppers'),
#     ('Frax777', 1, (3, 25), '2022-02-07, 23:49:10')),
#    (('All the Way Up (remix)', 'Fat Joe'),
#     ('Frax777', 172, (4, 45), '2022-02-09, 22:23:04')),
#    (('Te Desheredo', 'Los Tres'),
#     ('Frax777', 81, (4, 48), '2022-02-09, 02:20:10')),
#    (('Papi ¿Dónde Está el Funk?', 'Los Tetas'),
#     ('Frax777', -3, (5, 50), '2022-02-08, 17:04:02')),
#    (('Tell Me Baby', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (4, 7), '2022-02-08, 00:25:44')),
#    (('Piola', 'Bronko Yotte'),
#     ('Frax777', -9, (3, 25), '2022-02-10, 23:56:37')),
#    (('Piola', 'Bronko Yotte'),
#     ('Frax777', 1, (3, 25), '2022-02-10, 23:53:12')),
#    (('Kiss Me More (feat. SZA)', 'Doja Cat'),
#     ('Frax777', -1, (3, 28), '2022-02-10, 18:15:14')),
#    (('Kiss Me More (feat. SZA)', 'Doja Cat'),
#     ('Frax777', -102, (3, 28), '2022-02-10, 18:18:43')),
#    (('Strip My Mind', 'Red Hot Chili Peppers'),
#     ('Frax777', 1, (4, 19), '2022-02-07, 23:58:03')),
#    (("I Was Feeling Down, I Found a Nice Witch and We're Friends",
#      'In Love With a Ghost'),
#     ('Frax777', 81, (3, 50), '2022-02-10, 23:25:30')),
#    (("I Was Feeling Down, I Found a Nice Witch and We're Friends",
#      'In Love With a Ghost'),
#     ('Frax777', -1, (3, 50), '2022-02-10, 23:21:39')),
#    (("I Don't Do Drugs (feat. Ariana Grande)", 'Doja Cat'),
#     ('Frax777', 11, (3, 8), '2022-02-10, 21:18:01')),
#    (("I Don't Do Drugs (feat. Ariana Grande)", 'Doja Cat'),
#     ('Frax777', -1, (3, 8), '2022-02-10, 21:14:52')),
#    (('Que alegría', 'NVSCVR'),
#     ('Frax777', -57, (2, 32), '2022-02-10, 18:15:14')),
#    (('Que alegría', 'NVSCVR'),
#     ('Frax777', -2, (2, 32), '2022-02-10, 18:12:40')),
#    (('Esasi', 'Bronko Yotte'),
#     ('Frax777', -624, (3, 58), '2022-02-11, 00:17:24')),
#    (('Esasi', 'Bronko Yotte'),
#     ('Frax777', -57162, (3, 58), '2022-02-11, 00:31:46')),
#    (('Esasi', 'Bronko Yotte'),
#     ('Frax777', 5, (3, 58), '2022-02-11, 16:28:26')),
#    (('Pal Aifon', 'Pikette23'),
#     ('Frax777', -16754, (3, 46), '2022-02-09, 14:36:55')),
#    (('Pal Aifon', 'Pikette23'),
#     ('Frax777', -179, (3, 46), '2022-02-09, 13:59:28')),
#    (('You Right', 'Doja Cat'),
#     ('Frax777', -1, (3, 6), '2022-02-10, 18:30:32')),
#    (('You Right', 'Doja Cat'),
#     ('Frax777', -77, (3, 6), '2022-02-10, 18:33:39')),
#    (('Galvano', 'Bronko Yotte'),
#     ('Frax777', 25, (3, 18), '2022-02-10, 23:47:28')),
#    (('Galvano', 'Bronko Yotte'),
#     ('Frax777', 28, (3, 18), '2022-02-10, 23:50:22')),
#    (("Sí Po'", 'Diego Lorenzini'),
#     ('Frax777', 0, (3, 2), '2022-02-10, 14:10:11')),
#    (("Sí Po'", 'Diego Lorenzini'),
#     ('Frax777', -1, (3, 2), '2022-02-10, 13:36:46')),
#    (('Woman', 'Doja Cat'), ('Frax777', -2, (2, 52), '2022-02-09, 23:38:22')),
#    (('Woman', 'Doja Cat'),
#     ('Frax777', -35131, (2, 52), '2022-02-04, 01:32:15')),
#    (('Woman', 'Doja Cat'), ('Frax777', -1, (2, 52), '2022-02-04, 00:36:30')),
#    (('Droga', 'DavUS'), ('Frax777', -2, (2, 55), '2022-02-10, 17:48:36')),
#    (('Droga', 'DavUS'), ('Frax777', -85, (2, 55), '2022-02-10, 17:51:33')),
#    (('Dosed', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (5, 12), '2022-02-09, 23:33:10')),
#    (('Dosed', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (5, 12), '2022-02-04, 00:23:30')),
#    (('Hump de Bump', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (3, 33), '2022-02-09, 22:34:49')),
#    (('Hump de Bump', 'Red Hot Chili Peppers'),
#     ('Frax777', 0, (3, 33), '2022-02-07, 23:45:37')),
#    (('Merced', 'Bronko Yotte'),
#     ('Frax777', -1, (2, 53), '2022-02-04, 00:42:35')),
#    (('Merced', 'Bronko Yotte'),
#     ('Frax777', 0, (2, 53), '2022-02-09, 23:53:30')),
#    (('Dos en Uno', 'Los Tres'),
#     ('Frax777', 2, (5, 54), '2022-02-09, 02:11:00')),
#    (('21st Century', 'Red Hot Chili Peppers'),
#     ('Frax777', -1, (4, 22), '2022-02-10, 18:33:39')),
#    (('21st Century', 'Red Hot Chili Peppers'),
#     ('Frax777', -2, (4, 22), '2022-02-08, 13:03:16')),
#    (('21st Century', 'Red Hot Chili Peppers'),
#     ('Frax777', -426, (4, 22), '2022-02-10, 18:38:02')),
#    (('This Is the Place', 'Red Hot Chili Peppers'),
#     ('Frax777', -12, (4, 17), '2022-02-09, 23:59:35')),
#    (('If', 'Red Hot Chili Peppers'),
#     ('Frax777', -2988, (2, 52), '2022-02-08, 13:17:55')),
#    (('Consigue de To', 'Pikette23'),
#     ('Frax777', 71, (3, 46), '2022-02-09, 14:32:06')),
#    (('Consigue de To', 'Pikette23'),
#     ('Frax777', 71, (3, 46), '2022-02-09, 13:54:39')),
#    (('Whiskey in the Jar', 'Metallica'),
#     ('Frax777', -1, (5, 4), '2022-02-07, 21:49:47')),
#    (('En Otro', 'Young Dillinger'),
#     ('Frax777', 29, (4, 8), '2022-02-10, 18:09:01')),
#    (('En Otro', 'Young Dillinger'),
#     ('Frax777', 19, (4, 8), '2022-02-10, 18:05:12')),
#    (('En Otro', 'Young Dillinger'),
#     ('Frax777', 22, (4, 8), '2022-02-04, 01:17:59')),
#    (('Eras mi persona favorita', 'Teleradio Donoso'),
#     ('Frax777', -1, (3, 48), '2022-02-09, 00:30:26')),
#    (('Corazón de Sandía', 'Los Tetas'),
#     ('Frax777', -3, (3, 56), '2022-02-08, 16:42:41')),
#    (('Hojas de Té', 'Los Tres'),
#     ('Frax777', 1, (3, 37), '2022-02-09, 02:02:21')),
#    (('Tírate', 'Los Tres'),
#     ('Frax777', -289, (3, 16), '2022-02-08, 23:50:27')),
#    (('Tírate', 'Los Tres'), ('Frax777', -2, (3, 16), '2022-02-09, 02:16:52')),
#    (('The Day That Never Comes', 'Metallica'),
#     ('Frax777', -1, (8, 35), '2022-02-07, 21:14:09')),
#    (('The Day That Never Comes', 'Metallica'),
#     ('Frax777', -66228, (8, 35), '2022-02-07, 02:41:46')),
#    (('Plan Maestro', 'Diego Lorenzini'),
#     ('Frax777', -1, (2, 27), '2022-02-10, 13:39:49')),
#    (('Plan Maestro', 'Diego Lorenzini'),
#     ('Frax777', -1, (2, 27), '2022-02-10, 14:13:13')),
#    (('Chica eléctrica', 'La Pozze Latina'),
#     ('Frax777', -4958, (5, 28), '2022-02-09, 00:34:15')),
#    (('Smells Like Teen Spirit', 'Nirvana'),
#     ('Frax777', 150, (5, 1), '2022-02-07, 22:39:37')),
#    (('Black Summer', 'Red Hot Chili Peppers'),
#     ('Frax777', 208, (5, 39), '2022-02-07, 22:33:27')),
#    (('Black Summer', 'Red Hot Chili Peppers'),
#     ('Frax777', -7130, (5, 39), '2022-02-04, 11:20:38')),
#    (('Black Summer', 'Red Hot Chili Peppers'),
#     ('Frax777', 109, (5, 39), '2022-02-06, 21:12:45')),
#    (('Black Summer', 'Red Hot Chili Peppers'),
#     ('Frax777', 106, (5, 39), '2022-02-09, 14:18:07')),
#    (('Nothing Else Matters', 'Metallica'),
#     ('Frax777', -36, (5, 52), '2022-02-07, 21:28:16')),
#    (('Nothing Else Matters', 'Metallica'),
#     ('Frax777', 106, (5, 52), '2022-02-07, 02:37:40')),
#    (('The Unforgiven', 'Metallica'),
#     ('Frax777', 26, (6, 53), '2022-02-07, 21:43:20')),
#    (('Tu Pirata Soy Yo', 'Gepe'),
#     ('Frax777', -21, (2, 47), '2022-02-05, 19:58:24')),
#    (('I Could Die for You', 'Red Hot Chili Peppers'),
#     ('Frax777', 1, (3, 13), '2022-02-10, 00:04:04')),
#    (('positions', 'Ariana Grande'),
#     ('Frax777', -7435, (3, 47), '2022-02-08, 14:10:35')),
#    (('positions', 'Ariana Grande'),
#     ('Frax777', 54, (3, 47), '2022-02-04, 01:26:22')),
#    (('positions', 'Ariana Grande'),
#     ('Frax777', 58, (3, 47), '2022-02-10, 17:39:20')),
#    (('Explorador', 'Fother Muckers'),
#     ('Frax777', -1, (2, 51), '2022-02-08, 17:09:55')),
#    (('Jaguar', 'Pablo Chill-E'),
#     ('Frax777', -1, (3, 15), '2022-02-10, 21:04:20')),
#    (('Jaguar', 'Pablo Chill-E'),
#     ('Frax777', 62, (3, 15), '2022-02-10, 21:07:36')),
#    (('Coba', 'Pikette23'), ('Frax777', -80, (2, 13), '2022-02-03, 23:53:59')),
#    (('Coba', 'Pikette23'), ('Frax777', 0, (2, 13), '2022-02-03, 23:51:46')),
#    (('Let Em Know', "ill' j"),
#     ('Frax777', 0, (2, 34), '2022-02-10, 18:27:58')),
#    (('Let Em Know', "ill' j"),
#     ('Frax777', -33, (2, 34), '2022-02-10, 18:30:32')),
#    (('No Church In The Wild', 'JAY-Z'),
#     ('Frax777', 39, (4, 8), '2022-02-10, 21:25:53')),
#    (('No Church In The Wild', 'JAY-Z'),
#     ('Frax777', -25, (4, 8), '2022-02-10, 21:21:20')),
#    (('Institutionalized', 'Kendrick Lamar'),
#     ('Frax777', -117, (4, 31), '2022-02-07, 23:21:37')),
#    (('Déjalo', 'De Saloon'), ('Frax777', -1, (3, 40), '2022-02-08, 23:33:54')),
#    (('La mano', 'Bronko Yotte'),
#     ('Frax777', -2886, (3, 26), '2022-02-11, 16:44:28')),
#    (('La mano', 'Bronko Yotte'),
#     ('Frax777', 19, (3, 26), '2022-02-10, 23:47:14')),
#    (('La mano', 'Bronko Yotte'),
#     ('Frax777', -864770, (3, 26), '2022-02-11, 17:36:00')),
#    (('La mano', 'Bronko Yotte'),
#     ('Frax777', -2, (3, 26), '2022-02-10, 23:43:46')),
#    (('SCOOP (feat. Doja Cat)', 'Lil Nas X'),
#     ('Frax777', -2, (2, 54), '2022-02-10, 17:42:09')),
#    (('SCOOP (feat. Doja Cat)', 'Lil Nas X'),
#     ('Frax777', -37, (2, 54), '2022-02-10, 17:45:05')),
#    (('SCOOP (feat. Doja Cat)', 'Lil Nas X'),
#     ('Frax777', -45, (2, 54), '2022-02-08, 16:18:17')),
#    (('Lophophora', 'Chancho En Piedra'),
#     ('Frax777', -1, (2, 21), '2022-02-08, 23:44:15')),
#    (('Love to Dream', 'Doja Cat'),
#     ('Frax777', -1, (3, 36), '2022-02-04, 00:49:47')),
#    (('ZOOM', 'Gianluca'), ('Frax777', -1, (2, 43), '2022-02-09, 23:10:31')),
#    (('INDUSTRY BABY (feat. Jack Harlow)', 'Lil Nas X'),
#     ('Frax777', -1, (3, 32), '2022-02-03, 23:53:59')),
#    (('En la Calle No Hay Pena', 'Pikette23'),
#     ('Frax777', 42, (3, 46), '2022-02-09, 14:06:13'))])]

# %% [markdown]
# if the difference is > 0, it means that some time passed after the track has been played in full, before getting to the next song. This is what we are looking for. If this value is bigger than some threshold, we consider the session finished.

# %% [markdown]
# If the song has a value `> 0 + threshold` (let's say 15 seconds), it means that it is the last song of the listening session, so from the next song we create a new listening session.

# %%
threshold = 15 # seconds

def get_sessions_per_user(x):
  all_tracks = sorted(x[1], key=lambda x: x[1][3])
  sessions = []
  temp = []
  for track in all_tracks:
    temp.append(track)
    if track[1][1] > threshold:
      sessions.append(temp)
      temp = []
  return sessions

user_sessions = sessions_tracks.map(lambda x: (x[0],get_sessions_per_user(x)))
user_sessions.take(20)
# Out:
# [('Frax777',
#   [[(('Coba', 'Pikette23'), ('Frax777', 0, (2, 13), '2022-02-03, 23:51:46')),
#     (('Coba', 'Pikette23'), ('Frax777', -80, (2, 13), '2022-02-03, 23:53:59')),
#     (('INDUSTRY BABY (feat. Jack Harlow)', 'Lil Nas X'),
#      ('Frax777', -1, (3, 32), '2022-02-03, 23:53:59')),
#     (('Ateo', 'C. Tangana'), ('Frax777', -2, (3, 59), '2022-02-03, 23:57:32')),
#     (('God is a woman', 'Ariana Grande'),
#      ('Frax777', 29, (3, 47), '2022-02-04, 00:01:33'))],
#    [(('Ateo', 'C. Tangana'),
#      ('Frax777', 41, (3, 59), '2022-02-04, 00:01:33'))],
#    [(('Este Año No Hay Cosecha', 'Pikette23'),
#      ('Frax777', 0, (2, 50), '2022-02-04, 00:04:51')),
#     (('Este Año No Hay Cosecha', 'Pikette23'),
#      ('Frax777', -59, (2, 50), '2022-02-04, 00:07:41')),
#     (('Ay Dios Mio', 'DavUS'),
#      ('Frax777', -81, (2, 28), '2022-02-04, 00:07:41')),
#     (('Van Damme / Grupo aparte', 'Bronko Yotte'),
#      ('Frax777', 1, (2, 38), '2022-02-04, 00:11:30')),
#     (('Revolución en Estéreo', 'Cultura Profética'),
#      ('Frax777', -89, (4, 8), '2022-02-04, 00:14:07')),
#     (('Van Damme / Grupo aparte', 'Bronko Yotte'),
#      ('Frax777', -179, (2, 38), '2022-02-04, 00:14:07')),
#     (('Revolución en Estéreo', 'Cultura Profética'),
#      ('Frax777', 22, (4, 8), '2022-02-04, 00:19:44'))],
#    [(('Mi Coraozn', 'Pikette23'),
#      ('Frax777', 0, (3, 46), '2022-02-04, 00:19:44')),
#     (('Mi Coraozn', 'Pikette23'),
#      ('Frax777', -87, (3, 46), '2022-02-04, 00:23:30')),
#     (('Dosed', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (5, 12), '2022-02-04, 00:23:30')),
#     (('Salmo', 'Bronko Yotte'),
#      ('Frax777', -1, (3, 25), '2022-02-04, 00:28:43')),
#     (('Yavida', 'Cultura Profética'),
#      ('Frax777', -13, (4, 8), '2022-02-04, 00:32:09')),
#     (('Salmo', 'Bronko Yotte'),
#      ('Frax777', -56, (3, 25), '2022-02-04, 00:32:09')),
#     (('Yavida', 'Cultura Profética'),
#      ('Frax777', 75, (4, 8), '2022-02-04, 00:36:30'))],
#    [(('Woman', 'Doja Cat'), ('Frax777', -1, (2, 52), '2022-02-04, 00:36:30')),
#     (('BANANA', 'Gianluca'), ('Frax777', -2, (3, 10), '2022-02-04, 00:39:23')),
#     (('Merced', 'Bronko Yotte'),
#      ('Frax777', -1, (2, 53), '2022-02-04, 00:42:35')),
#     (('Universally Speaking', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (4, 17), '2022-02-04, 00:45:29')),
#     (('Love to Dream', 'Doja Cat'),
#      ('Frax777', -1, (3, 36), '2022-02-04, 00:49:47')),
#     (('Use Your Body', 'Dreya Mac'),
#      ('Frax777', -845, (2, 59), '2022-02-04, 00:53:24')),
#     (('Tú Me Dejaste De Querer', 'C. Tangana'),
#      ('Frax777', -24, (3, 18), '2022-02-04, 01:10:28')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', 30, (4, 19), '2022-02-04, 01:14:10'))],
#    [(('En Otro', 'Young Dillinger'),
#      ('Frax777', 22, (4, 8), '2022-02-04, 01:17:59'))],
#    [(('Moizefala', 'Los Tres'),
#      ('Frax777', -1, (4, 36), '2022-02-04, 01:21:45')),
#     (('positions', 'Ariana Grande'),
#      ('Frax777', 54, (3, 47), '2022-02-04, 01:26:22'))],
#    [(('Use Your Body', 'Dreya Mac'),
#      ('Frax777', -1, (2, 59), '2022-02-04, 01:29:15')),
#     (('Use Your Body', 'Dreya Mac'),
#      ('Frax777', -35124, (2, 59), '2022-02-04, 01:32:15')),
#     (('Woman', 'Doja Cat'),
#      ('Frax777', -35131, (2, 52), '2022-02-04, 01:32:15')),
#     (('Black Summer', 'Red Hot Chili Peppers'),
#      ('Frax777', -7130, (5, 39), '2022-02-04, 11:20:38')),
#     (('Gone', 'Jorja Smith'), ('Frax777', 0, (3, 15), '2022-02-04, 13:25:07')),
#     (('Gone', 'Jorja Smith'),
#      ('Frax777', -88, (3, 15), '2022-02-04, 13:28:22')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', 2, (4, 19), '2022-02-04, 13:28:48')),
#     (('Libre', 'Gepe'), ('Frax777', -1, (3, 28), '2022-02-04, 13:33:05')),
#     (('Campos Magnéticos', 'Gepe'),
#      ('Frax777', -1, (3, 37), '2022-02-04, 13:36:34')),
#     (('Lluvia diente lluvia', 'Gepe'),
#      ('Frax777', -1, (1, 39), '2022-02-04, 13:40:12')),
#     (('Bailar bien, bailar mal', 'Gepe'),
#      ('Frax777', 0, (3, 45), '2022-02-04, 13:41:52')),
#     (('Platina', 'Gepe'), ('Frax777', -1, (3, 39), '2022-02-04, 13:45:37')),
#     (('Platina', 'Gepe'), ('Frax777', 33, (3, 39), '2022-02-04, 13:49:17'))],
#    [(('Bomba Chaya', 'Gepe'), ('Frax777', 1, (3, 7), '2022-02-04, 13:49:17')),
#     (('Un Gran Vacío', 'Gepe'),
#      ('Frax777', -10941, (6, 1), '2022-02-04, 13:52:23')),
#     (('Californication', 'Red Hot Chili Peppers'),
#      ('Frax777', -69865, (5, 21), '2022-02-04, 17:00:45')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', -24802, (4, 19), '2022-02-05, 12:30:31')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', 1, (4, 19), '2022-02-05, 19:28:12')),
#     (('Libre', 'Gepe'), ('Frax777', -1, (3, 28), '2022-02-05, 19:32:30')),
#     (('Campos Magnéticos', 'Gepe'),
#      ('Frax777', -8, (3, 37), '2022-02-05, 19:35:59')),
#     (('Platina', 'Gepe'), ('Frax777', -38, (3, 39), '2022-02-05, 19:39:44')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', 52, (4, 19), '2022-02-05, 19:44:01'))],
#    [(('Platina', 'Gepe'), ('Frax777', 1, (3, 39), '2022-02-05, 19:47:28')),
#     (('Bomba Chaya', 'Gepe'),
#      ('Frax777', -46, (3, 7), '2022-02-05, 19:51:06')),
#     (('Ser Amigos', 'Gepe'), ('Frax777', 1, (3, 26), '2022-02-05, 19:54:59')),
#     (('Tu Pirata Soy Yo', 'Gepe'),
#      ('Frax777', -21, (2, 47), '2022-02-05, 19:58:24')),
#     (('Dani California', 'Red Hot Chili Peppers'),
#      ('Frax777', 2, (4, 43), '2022-02-05, 20:01:32')),
#     (('Snow (Hey Oh)', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (5, 34), '2022-02-05, 20:06:13')),
#     (('Charlie', 'Red Hot Chili Peppers'),
#      ('Frax777', -16897, (4, 37), '2022-02-05, 20:11:48')),
#     (('Dani California', 'Red Hot Chili Peppers'),
#      ('Frax777', -652, (4, 43), '2022-02-06, 00:58:02')),
#     (('Californication', 'Red Hot Chili Peppers'),
#      ('Frax777', -71627, (5, 21), '2022-02-06, 01:13:37')),
#     (('Black Summer', 'Red Hot Chili Peppers'),
#      ('Frax777', 109, (5, 39), '2022-02-06, 21:12:45'))],
#    [(('Dani California', 'Red Hot Chili Peppers'),
#      ('Frax777', 2, (4, 43), '2022-02-06, 21:16:35')),
#     (('Snow (Hey Oh)', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (5, 34), '2022-02-06, 21:21:16')),
#     (('Charlie', 'Red Hot Chili Peppers'),
#      ('Frax777', -18372, (4, 37), '2022-02-06, 21:26:51')),
#     (('Nothing Else Matters', 'Metallica'),
#      ('Frax777', 106, (5, 52), '2022-02-07, 02:37:40'))],
#    [(('The Day That Never Comes', 'Metallica'),
#      ('Frax777', -66228, (8, 35), '2022-02-07, 02:41:46')),
#     (('The Day That Never Comes', 'Metallica'),
#      ('Frax777', -1, (8, 35), '2022-02-07, 21:14:09')),
#     (('Enter Sandman', 'Metallica'),
#      ('Frax777', 62, (6, 33), '2022-02-07, 21:22:45'))],
#    [(('Nothing Else Matters', 'Metallica'),
#      ('Frax777', -36, (5, 52), '2022-02-07, 21:28:16')),
#     (('Master of Puppets', 'Metallica'),
#      ('Frax777', -1, (8, 35), '2022-02-07, 21:34:44')),
#     (('The Unforgiven', 'Metallica'),
#      ('Frax777', 26, (6, 53), '2022-02-07, 21:43:20'))],
#    [(('Whiskey in the Jar', 'Metallica'),
#      ('Frax777', -1, (5, 4), '2022-02-07, 21:49:47')),
#     (('One', 'Metallica'), ('Frax777', -4, (7, 24), '2022-02-07, 21:54:52')),
#     (('For Whom The Bell Tolls - Remastered', 'Metallica'),
#      ('Frax777', 61, (5, 9), '2022-02-07, 22:02:20'))],
#    [(('Enter Sandman', 'Metallica'),
#      ('Frax777', -1226, (6, 33), '2022-02-07, 22:06:28')),
#     (('Black Summer', 'Red Hot Chili Peppers'),
#      ('Frax777', 208, (5, 39), '2022-02-07, 22:33:27'))],
#    [(('Especially in Michigan', 'Red Hot Chili Peppers'),
#      ('Frax777', 2, (4, 1), '2022-02-07, 22:35:38')),
#     (('Smells Like Teen Spirit', 'Nirvana'),
#      ('Frax777', 150, (5, 1), '2022-02-07, 22:39:37'))],
#    [(('Gone', 'Jorja Smith'),
#      ('Frax777', -2174, (3, 15), '2022-02-07, 22:42:08')),
#     (('Institutionalized', 'Kendrick Lamar'),
#      ('Frax777', -117, (4, 31), '2022-02-07, 23:21:37')),
#     (('Dani California', 'Red Hot Chili Peppers'),
#      ('Frax777', -5, (4, 43), '2022-02-07, 23:28:05')),
#     (('Snow (Hey Oh)', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (5, 34), '2022-02-07, 23:32:53')),
#     (('Charlie', 'Red Hot Chili Peppers'),
#      ('Frax777', -153, (4, 37), '2022-02-07, 23:38:27')),
#     (('Hump de Bump', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (3, 33), '2022-02-07, 23:45:37')),
#     (("She's Only 18", 'Red Hot Chili Peppers'),
#      ('Frax777', 1, (3, 25), '2022-02-07, 23:49:10')),
#     (('Slow Cheetah', 'Red Hot Chili Peppers'),
#      ('Frax777', -9, (5, 20), '2022-02-07, 23:52:34')),
#     (('Strip My Mind', 'Red Hot Chili Peppers'),
#      ('Frax777', 1, (4, 19), '2022-02-07, 23:58:03')),
#     (('Especially in Michigan', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (4, 1), '2022-02-08, 00:02:21')),
#     (('Warlocks', 'Red Hot Chili Peppers'),
#      ('Frax777', -6, (3, 25), '2022-02-08, 00:06:22')),
#     (('Wet Sand', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (5, 9), '2022-02-08, 00:09:53')),
#     (('Hey', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (5, 39), '2022-02-08, 00:15:02')),
#     (('Desecration Smile', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (5, 2), '2022-02-08, 00:20:42')),
#     (('Tell Me Baby', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (4, 7), '2022-02-08, 00:25:44')),
#     (('Hard to Concentrate', 'Red Hot Chili Peppers'),
#      ('Frax777', -44962, (4, 2), '2022-02-08, 00:29:52')),
#     (('21st Century', 'Red Hot Chili Peppers'),
#      ('Frax777', -2, (4, 22), '2022-02-08, 13:03:16')),
#     (('She Looks to Me', 'Red Hot Chili Peppers'),
#      ('Frax777', 1, (4, 6), '2022-02-08, 13:07:40')),
#     (('Readymade', 'Red Hot Chili Peppers'),
#      ('Frax777', -100, (4, 30), '2022-02-08, 13:11:45')),
#     (('If', 'Red Hot Chili Peppers'),
#      ('Frax777', -2988, (2, 52), '2022-02-08, 13:17:55')),
#     (('positions', 'Ariana Grande'),
#      ('Frax777', -7435, (3, 47), '2022-02-08, 14:10:35')),
#     (('TDG Crew', 'Tiro De Gracia'),
#      ('Frax777', 0, (3, 39), '2022-02-08, 16:18:17')),
#     (('SCOOP (feat. Doja Cat)', 'Lil Nas X'),
#      ('Frax777', -45, (2, 54), '2022-02-08, 16:18:17')),
#     (('Pedro Pesado', 'Tiro De Gracia'),
#      ('Frax777', 0, (3, 0), '2022-02-08, 16:21:56')),
#     (('Lo Que Ven Mis Ojos', 'Tiro De Gracia'),
#      ('Frax777', -2, (3, 40), '2022-02-08, 16:24:56')),
#     (('Ser hümano', 'Tiro De Gracia'),
#      ('Frax777', 208, (5, 21), '2022-02-08, 16:28:38'))],
#    [(('Dejando Libre el Amor', 'Chancho En Piedra'),
#      ('Frax777', -1, (4, 22), '2022-02-08, 16:30:31')),
#     (('Moizefala', 'Los Tres'),
#      ('Frax777', -1, (4, 36), '2022-02-08, 16:34:54')),
#     (('Alturas', 'Inti-Illimani'),
#      ('Frax777', 0, (3, 10), '2022-02-08, 16:39:31')),
#     (('Corazón de Sandía', 'Los Tetas'),
#      ('Frax777', -3, (3, 56), '2022-02-08, 16:42:41')),
#     (('TDG Crew', 'Tiro De Gracia'),
#      ('Frax777', -22, (3, 39), '2022-02-08, 16:46:40')),
#     (('Mi Mejor Momento', 'Chancho En Piedra'),
#      ('Frax777', 1, (3, 23), '2022-02-08, 16:50:41')),
#     (('Amar en el campo', 'Teleradio Donoso'),
#      ('Frax777', -1, (3, 57), '2022-02-08, 16:54:03')),
#     (('Vacaciones en el más allá', 'Pedropiedra'),
#      ('Frax777', -1, (3, 52), '2022-02-08, 16:58:01')),
#     (('Nuestra Fiesta (okupa, segura y no molesta)', 'Tiro De Gracia'),
#      ('Frax777', -1, (2, 7), '2022-02-08, 17:01:54')),
#     (('Papi ¿Dónde Está el Funk?', 'Los Tetas'),
#      ('Frax777', -3, (5, 50), '2022-02-08, 17:04:02')),
#     (('Explorador', 'Fother Muckers'),
#      ('Frax777', -1, (2, 51), '2022-02-08, 17:09:55')),
#     (('Cerrar y Abrir', 'Los Tres'),
#      ('Frax777', -1, (4, 14), '2022-02-08, 17:12:47')),
#     (('Cuando quieras', 'Guachupé'),
#      ('Frax777', -22238, (3, 53), '2022-02-08, 17:17:02')),
#     (('Amor Enfermizo', 'Tiro De Gracia'),
#      ('Frax777', -1, (2, 20), '2022-02-08, 23:31:33')),
#     (('Déjalo', 'De Saloon'),
#      ('Frax777', -1, (3, 40), '2022-02-08, 23:33:54')),
#     (('Bailar y Llorar', 'Teleradio Donoso'),
#      ('Frax777', 0, (3, 49), '2022-02-08, 23:37:35')),
#     (('Era de verdad', 'Hordatoj'),
#      ('Frax777', -2, (2, 49), '2022-02-08, 23:41:24')),
#     (('Lophophora', 'Chancho En Piedra'),
#      ('Frax777', -1, (2, 21), '2022-02-08, 23:44:15')),
#     (('Corsario Universal', 'Tiro De Gracia'),
#      ('Frax777', -4, (3, 46), '2022-02-08, 23:46:37')),
#     (('Tírate', 'Los Tres'),
#      ('Frax777', -289, (3, 16), '2022-02-08, 23:50:27')),
#     (('Mataz', 'Lucybell'), ('Frax777', -72, (5, 49), '2022-02-08, 23:58:32')),
#     (('Carnavalito del ciempiés', 'Nano Stern'),
#      ('Frax777', -411, (4, 8), '2022-02-09, 00:05:33')),
#     (('La Medicina', 'Los Tetas'),
#      ('Frax777', -36, (4, 0), '2022-02-09, 00:16:32')),
#     (('Sueños', 'Tiro De Gracia'),
#      ('Frax777', -1, (5, 21), '2022-02-09, 00:21:08')),
#     (('imagino', 'Hordatoj'),
#      ('Frax777', -1, (3, 55), '2022-02-09, 00:26:30')),
#     (('Eras mi persona favorita', 'Teleradio Donoso'),
#      ('Frax777', -1, (3, 48), '2022-02-09, 00:30:26')),
#     (('Chica eléctrica', 'La Pozze Latina'),
#      ('Frax777', -4958, (5, 28), '2022-02-09, 00:34:15')),
#     (('Hojas de Té', 'Los Tres'),
#      ('Frax777', 1, (3, 37), '2022-02-09, 02:02:21')),
#     (('La Espada & la Pared', 'Los Tres'),
#      ('Frax777', 232, (8, 55), '2022-02-09, 02:05:57'))],
#    [(('Dos en Uno', 'Los Tres'),
#      ('Frax777', 2, (5, 54), '2022-02-09, 02:11:00')),
#     (('Tírate', 'Los Tres'), ('Frax777', -2, (3, 16), '2022-02-09, 02:16:52')),
#     (('Te Desheredo', 'Los Tres'),
#      ('Frax777', 81, (4, 48), '2022-02-09, 02:20:10'))],
#    [(('Dani California', 'Red Hot Chili Peppers'),
#      ('Frax777', -820, (4, 43), '2022-02-09, 02:23:37')),
#     (('Snow (Hey Oh)', 'Red Hot Chili Peppers'),
#      ('Frax777', -39667, (5, 34), '2022-02-09, 02:42:00')),
#     (('Parte 2', 'Pikette23'),
#      ('Frax777', -132, (3, 46), '2022-02-09, 13:48:41')),
#     (('Incertidumbre', 'Pikette23'),
#      ('Frax777', 71, (3, 46), '2022-02-09, 13:54:39'))],
#    [(('Consigue de To', 'Pikette23'),
#      ('Frax777', 71, (3, 46), '2022-02-09, 13:54:39'))],
#    [(('Galactica', 'Pikette23'),
#      ('Frax777', 92, (3, 46), '2022-02-09, 13:57:14'))],
#    [(('Pal Aifon', 'Pikette23'),
#      ('Frax777', -179, (3, 46), '2022-02-09, 13:59:28')),
#     (('En la Calle No Hay Pena', 'Pikette23'),
#      ('Frax777', 42, (3, 46), '2022-02-09, 14:06:13'))],
#    [(('Extraordinario', 'Pikette23'),
#      ('Frax777', -1, (3, 46), '2022-02-09, 14:09:17')),
#     (('Mi Coraozn', 'Pikette23'),
#      ('Frax777', -77, (3, 46), '2022-02-09, 14:13:04')),
#     (('Black Summer', 'Red Hot Chili Peppers'),
#      ('Frax777', 106, (5, 39), '2022-02-09, 14:18:07'))],
#    [(('Especially in Michigan', 'Red Hot Chili Peppers'),
#      ('Frax777', 10, (4, 1), '2022-02-09, 14:22:00')),
#     (('Parte 2', 'Pikette23'),
#      ('Frax777', 14, (3, 46), '2022-02-09, 14:25:51')),
#     (('Incertidumbre', 'Pikette23'),
#      ('Frax777', 63, (3, 46), '2022-02-09, 14:29:23'))],
#    [(('Consigue de To', 'Pikette23'),
#      ('Frax777', 71, (3, 46), '2022-02-09, 14:32:06'))],
#    [(('Galactica', 'Pikette23'),
#      ('Frax777', 92, (3, 46), '2022-02-09, 14:34:41'))],
#    [(('Pal Aifon', 'Pikette23'),
#      ('Frax777', -16754, (3, 46), '2022-02-09, 14:36:55')),
#     (("What's Luv? (Feat. Ja-Rule & Ashanti)", 'Fat Joe'),
#      ('Frax777', -1, (4, 27), '2022-02-09, 19:19:55')),
#     (('Sunshine (The Light)', 'Fat Joe'),
#      ('Frax777', 0, (2, 29), '2022-02-09, 19:24:23')),
#     (('All The Way Up', 'Fat Joe'),
#      ('Frax777', -10381, (3, 11), '2022-02-09, 19:26:52')),
#     (('All the Way Up (remix)', 'Fat Joe'),
#      ('Frax777', 172, (4, 45), '2022-02-09, 22:23:04'))],
#    [(('Charlie', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (4, 37), '2022-02-09, 22:24:57')),
#     (('Stadium Arcadium', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (5, 15), '2022-02-09, 22:29:34')),
#     (('Hump de Bump', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (3, 33), '2022-02-09, 22:34:49')),
#     (("She's Only 18", 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (3, 25), '2022-02-09, 22:38:22')),
#     (('Slow Cheetah', 'Red Hot Chili Peppers'),
#      ('Frax777', -23, (5, 20), '2022-02-09, 22:41:48')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', -182, (4, 19), '2022-02-09, 22:47:31')),
#     (('Campos Magnéticos', 'Gepe'),
#      ('Frax777', -3, (3, 37), '2022-02-09, 22:54:52')),
#     (('Bailar bien, bailar mal', 'Gepe'),
#      ('Frax777', 0, (3, 45), '2022-02-09, 22:58:32')),
#     (('Platina', 'Gepe'), ('Frax777', -35, (3, 39), '2022-02-09, 23:02:17')),
#     (('Ateo', 'C. Tangana'), ('Frax777', -1, (3, 59), '2022-02-09, 23:06:31')),
#     (('ZOOM', 'Gianluca'), ('Frax777', -1, (2, 43), '2022-02-09, 23:10:31')),
#     (('THATS WHAT I WANT', 'Lil Nas X'),
#      ('Frax777', 62, (3, 32), '2022-02-09, 23:13:15'))],
#    [(('Van Damme / Grupo aparte', 'Bronko Yotte'),
#      ('Frax777', 0, (2, 38), '2022-02-09, 23:15:45')),
#     (('Este Año No Hay Cosecha', 'Pikette23'),
#      ('Frax777', -7, (2, 50), '2022-02-09, 23:18:23')),
#     (('Ay Dios Mio', 'DavUS'),
#      ('Frax777', 0, (2, 28), '2022-02-09, 23:21:20')),
#     (('Revolución en Estéreo', 'Cultura Profética'),
#      ('Frax777', -88, (4, 8), '2022-02-09, 23:23:48')),
#     (('Mi Coraozn', 'Pikette23'),
#      ('Frax777', 0, (3, 46), '2022-02-09, 23:29:24')),
#     (('Dosed', 'Red Hot Chili Peppers'),
#      ('Frax777', 0, (5, 12), '2022-02-09, 23:33:10')),
#     (('Woman', 'Doja Cat'), ('Frax777', -2, (2, 52), '2022-02-09, 23:38:22')),
#     (('Salmo', 'Bronko Yotte'),
#      ('Frax777', -1, (3, 25), '2022-02-09, 23:41:16')),
#     (('Yavida', 'Cultura Profética'),
#      ('Frax777', -13, (4, 8), '2022-02-09, 23:44:42')),
#     (('Universally Speaking', 'Red Hot Chili Peppers'),
#      ('Frax777', -10, (4, 17), '2022-02-09, 23:49:03')),
#     (('Merced', 'Bronko Yotte'),
#      ('Frax777', 0, (2, 53), '2022-02-09, 23:53:30')),
#     (('BANANA', 'Gianluca'), ('Frax777', -2, (3, 10), '2022-02-09, 23:56:23')),
#     (('This Is the Place', 'Red Hot Chili Peppers'),
#      ('Frax777', -12, (4, 17), '2022-02-09, 23:59:35')),
#     (('I Could Die for You', 'Red Hot Chili Peppers'),
#      ('Frax777', 1, (3, 13), '2022-02-10, 00:04:04')),
#     (('Del Tope al Fondo', 'Cultura Profética'),
#      ('Frax777', -60, (4, 8), '2022-02-10, 00:07:16')),
#     (('XANDER FREESTYLE', 'Gianluca'),
#      ('Frax777', -46702, (1, 43), '2022-02-10, 00:12:24')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', -16, (4, 19), '2022-02-10, 13:12:29')),
#     (('Platina', 'Gepe'), ('Frax777', -45, (3, 39), '2022-02-10, 13:17:04')),
#     (('Nuestra Fiesta (okupa, segura y no molesta)', 'Tiro De Gracia'),
#      ('Frax777', 5, (2, 7), '2022-02-10, 13:21:28')),
#     (('Corsario Universal', 'Tiro De Gracia'),
#      ('Frax777', -55, (3, 46), '2022-02-10, 13:23:30')),
#     (('Sombras Chinescas', 'Tiro De Gracia'),
#      ('Frax777', -81, (3, 53), '2022-02-10, 13:28:11')),
#     (('Spoiler', 'Diego Lorenzini'),
#      ('Frax777', 0, (3, 21), '2022-02-10, 13:33:25')),
#     (("Sí Po'", 'Diego Lorenzini'),
#      ('Frax777', -1, (3, 2), '2022-02-10, 13:36:46')),
#     (('Plan Maestro', 'Diego Lorenzini'),
#      ('Frax777', -1, (2, 27), '2022-02-10, 13:39:49')),
#     (('Chao Mi Niño', 'Diego Lorenzini'),
#      ('Frax777', -1082, (2, 13), '2022-02-10, 13:42:17')),
#     (('Me voy a Valparaíso', 'Diego Lorenzini'),
#      ('Frax777', 13, (4, 32), '2022-02-10, 14:02:32')),
#     (('Spoiler', 'Diego Lorenzini'),
#      ('Frax777', 1, (3, 21), '2022-02-10, 14:06:51')),
#     (("Sí Po'", 'Diego Lorenzini'),
#      ('Frax777', 0, (3, 2), '2022-02-10, 14:10:11')),
#     (('Plan Maestro', 'Diego Lorenzini'),
#      ('Frax777', -1, (2, 27), '2022-02-10, 14:13:13')),
#     (('Chao Mi Niño', 'Diego Lorenzini'),
#      ('Frax777', -1, (2, 13), '2022-02-10, 14:15:41')),
#     (('Pony', 'Diego Lorenzini'),
#      ('Frax777', 0, (3, 28), '2022-02-10, 14:17:55')),
#     (('Valparaisito', 'Diego Lorenzini'),
#      ('Frax777', -11845, (0, 32), '2022-02-10, 14:21:23')),
#     (('Felipe Camiroaga', 'Diego Lorenzini'),
#      ('Frax777', -11572, (4, 32), '2022-02-10, 14:21:56')),
#     (('positions', 'Ariana Grande'),
#      ('Frax777', 58, (3, 47), '2022-02-10, 17:39:20'))],
#    [(('SCOOP (feat. Doja Cat)', 'Lil Nas X'),
#      ('Frax777', -2, (2, 54), '2022-02-10, 17:42:09')),
#     (('Need to Know', 'Doja Cat'),
#      ('Frax777', 5, (3, 36), '2022-02-10, 17:45:05')),
#     (('SCOOP (feat. Doja Cat)', 'Lil Nas X'),
#      ('Frax777', -37, (2, 54), '2022-02-10, 17:45:05')),
#     (('Need to Know', 'Doja Cat'),
#      ('Frax777', 39, (3, 36), '2022-02-10, 17:48:36'))],
#    [(('Droga', 'DavUS'), ('Frax777', -2, (2, 55), '2022-02-10, 17:48:36')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', -1, (4, 19), '2022-02-10, 17:51:33')),
#     (('Droga', 'DavUS'), ('Frax777', -85, (2, 55), '2022-02-10, 17:51:33')),
#     (('Dani California', 'Red Hot Chili Peppers'),
#      ('Frax777', 1, (4, 43), '2022-02-10, 17:55:53')),
#     (('Bacán tu casa', 'Gepe'),
#      ('Frax777', -23, (4, 19), '2022-02-10, 17:55:53')),
#     (('Dani California', 'Red Hot Chili Peppers'),
#      ('Frax777', 6, (4, 43), '2022-02-10, 18:00:35')),
#     (('Moizefala', 'Los Tres'),
#      ('Frax777', -1, (4, 36), '2022-02-10, 18:00:35')),
#     (('Moizefala', 'Los Tres'),
#      ('Frax777', 47, (4, 36), '2022-02-10, 18:05:12'))],
#    [(('En Otro', 'Young Dillinger'),
#      ('Frax777', 19, (4, 8), '2022-02-10, 18:05:12'))],
#    [(('Platina', 'Gepe'), ('Frax777', 0, (3, 39), '2022-02-10, 18:09:01')),
#     (('En Otro', 'Young Dillinger'),
#      ('Frax777', 29, (4, 8), '2022-02-10, 18:09:01'))],
#    [(('Platina', 'Gepe'), ('Frax777', 65, (3, 39), '2022-02-10, 18:12:40'))],
#    [(('Que alegría', 'NVSCVR'),
#      ('Frax777', -2, (2, 32), '2022-02-10, 18:12:40')),
#     (('Kiss Me More (feat. SZA)', 'Doja Cat'),
#      ('Frax777', -1, (3, 28), '2022-02-10, 18:15:14')),
#     (('Que alegría', 'NVSCVR'),
#      ('Frax777', -57, (2, 32), '2022-02-10, 18:15:14')),
#     (('Wet Sand', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (5, 9), '2022-02-10, 18:18:43')),
#     (('Kiss Me More (feat. SZA)', 'Doja Cat'),
#      ('Frax777', -102, (3, 28), '2022-02-10, 18:18:43')),
#     (('Wet Sand', 'Red Hot Chili Peppers'),
#      ('Frax777', 64, (5, 9), '2022-02-10, 18:23:53'))],
#    [(('Campos Magnéticos', 'Gepe'),
#      ('Frax777', -28, (3, 37), '2022-02-10, 18:23:53')),
#     (('Campos Magnéticos', 'Gepe'),
#      ('Frax777', 63, (3, 37), '2022-02-10, 18:27:58'))],
#    [(('Let Em Know', "ill' j"),
#      ('Frax777', 0, (2, 34), '2022-02-10, 18:27:58')),
#     (('You Right', 'Doja Cat'),
#      ('Frax777', -1, (3, 6), '2022-02-10, 18:30:32')),
#     (('Let Em Know', "ill' j"),
#      ('Frax777', -33, (2, 34), '2022-02-10, 18:30:32')),
#     (('You Right', 'Doja Cat'),
#      ('Frax777', -77, (3, 6), '2022-02-10, 18:33:39')),
#     (('21st Century', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (4, 22), '2022-02-10, 18:33:39')),
#     (('Bailar bien, bailar mal', 'Gepe'),
#      ('Frax777', -463, (3, 45), '2022-02-10, 18:38:02')),
#     (('21st Century', 'Red Hot Chili Peppers'),
#      ('Frax777', -426, (4, 22), '2022-02-10, 18:38:02')),
#     (('Bailar bien, bailar mal', 'Gepe'),
#      ('Frax777', -7865, (3, 45), '2022-02-10, 18:49:30')),
#     (('Bailar bien, bailar mal', 'Gepe'),
#      ('Frax777', 29, (3, 45), '2022-02-10, 21:04:20'))],
#    [(('Jaguar', 'Pablo Chill-E'),
#      ('Frax777', -1, (3, 15), '2022-02-10, 21:04:20')),
#     (('invierno', 'Gianluca'),
#      ('Frax777', -1, (2, 12), '2022-02-10, 21:07:36')),
#     (('Jaguar', 'Pablo Chill-E'),
#      ('Frax777', 62, (3, 15), '2022-02-10, 21:07:36'))],
#    [(('invierno', 'Gianluca'),
#      ('Frax777', -171, (2, 12), '2022-02-10, 21:09:49')),
#     (('Dark Necessities', 'Red Hot Chili Peppers'),
#      ('Frax777', -1, (5, 2), '2022-02-10, 21:09:49')),
#     (('Dark Necessities', 'Red Hot Chili Peppers'),
#      ('Frax777', 113, (5, 2), '2022-02-10, 21:14:52'))],
#    [(("I Don't Do Drugs (feat. Ariana Grande)", 'Doja Cat'),
#      ('Frax777', -1, (3, 8), '2022-02-10, 21:14:52')),
#     (('Counter Strike', 'DavUS'),
#      ('Frax777', 4, (3, 1), '2022-02-10, 21:18:01')),
#     (("I Don't Do Drugs (feat. Ariana Grande)", 'Doja Cat'),
#      ('Frax777', 11, (3, 8), '2022-02-10, 21:18:01')),
#     (('Counter Strike', 'DavUS'),
#      ('Frax777', 159, (3, 1), '2022-02-10, 21:20:58'))],
#    [(('No Church In The Wild', 'JAY-Z'),
#      ('Frax777', -25, (4, 8), '2022-02-10, 21:21:20')),
#     (('No Church In The Wild', 'JAY-Z'),
#      ('Frax777', 39, (4, 8), '2022-02-10, 21:25:53'))],
#    [(('Caught Their Eyes', 'JAY-Z'),
#      ('Frax777', 42, (4, 8), '2022-02-10, 21:25:56'))],
#    [(('Fade', 'Kanye West'),
#      ('Frax777', 85, (3, 13), '2022-02-10, 21:29:22'))],
#    [(('Caught Their Eyes', 'JAY-Z'),
#      ('Frax777', 140, (4, 8), '2022-02-10, 21:29:22'))],
#    [(('Born Sinner', 'Lecrae'),
#      ('Frax777', -23, (2, 12), '2022-02-10, 21:31:10')),
#     (('Born Sinner', 'Lecrae'),
#      ('Frax777', 64, (2, 12), '2022-02-10, 21:33:45'))],
#    [(('Endorfinas', 'Bronko Yotte'),
#      ('Frax777', -8, (3, 52), '2022-02-10, 21:34:53')),
#     (('flowers', 'In Love With a Ghost'),
#      ('Frax777', -575, (4, 12), '2022-02-10, 21:38:53')),
#     (('Endorfinas', 'Bronko Yotte'),
#      ('Frax777', -595, (3, 52), '2022-02-10, 21:38:53')),
#     (('flowers', 'In Love With a Ghost'),
#      ('Frax777', -5011, (4, 12), '2022-02-10, 21:52:40')),
#     (('flowers', 'In Love With a Ghost'),
#      ('Frax777', 176, (4, 12), '2022-02-10, 23:20:23'))],
#    [(('iced tea for breakfast', 'In Love With a Ghost'),
#      ('Frax777', 0, (1, 16), '2022-02-10, 23:20:23')),
#     (('iced tea for breakfast', 'In Love With a Ghost'),
#      ('Frax777', -155, (1, 16), '2022-02-10, 23:21:39')),
#     (("I Was Feeling Down, I Found a Nice Witch and We're Friends",
#       'In Love With a Ghost'),
#      ('Frax777', -1, (3, 50), '2022-02-10, 23:21:39')),
#     (('Puchero', 'Bronko Yotte'),
#      ('Frax777', 0, (2, 29), '2022-02-10, 23:25:30')),
#     (("I Was Feeling Down, I Found a Nice Witch and We're Friends",
#       'In Love With a Ghost'),
#      ('Frax777', 81, (3, 50), '2022-02-10, 23:25:30'))],
#    [(('Al Capone', 'Bronko Yotte'),
#      ('Frax777', 240, (4, 1), '2022-02-10, 23:27:59'))],
#    [(('Puchero', 'Bronko Yotte'),
#      ('Frax777', -92, (2, 29), '2022-02-10, 23:28:00')),
#     (('Si bien', 'Bronko Yotte'),
#      ('Frax777', -456, (4, 9), '2022-02-10, 23:32:01')),
#     (('Al Capone', 'Bronko Yotte'),
#      ('Frax777', -464, (4, 1), '2022-02-10, 23:32:01')),
#     (('La mano', 'Bronko Yotte'),
#      ('Frax777', -2, (3, 26), '2022-02-10, 23:43:46')),
#     (('Si bien', 'Bronko Yotte'),
#      ('Frax777', 42, (4, 9), '2022-02-10, 23:43:47'))],
#    [(('La mano', 'Bronko Yotte'),
#      ('Frax777', 19, (3, 26), '2022-02-10, 23:47:14'))],
#    [(('Galvano', 'Bronko Yotte'),
#      ('Frax777', 25, (3, 18), '2022-02-10, 23:47:28'))],
#    [(('Abajo', 'Bronko Yotte'),
#      ('Frax777', -1, (2, 50), '2022-02-10, 23:50:21')),
#     (('Galvano', 'Bronko Yotte'),
#      ('Frax777', 28, (3, 18), '2022-02-10, 23:50:22'))],
#    [(('Abajo', 'Bronko Yotte'),
#      ('Frax777', -34, (2, 50), '2022-02-10, 23:53:12')),
#     (('Piola', 'Bronko Yotte'),
#      ('Frax777', 1, (3, 25), '2022-02-10, 23:53:12')),
#     (('Cienfuegos', 'Bronko Yotte'),
#      ('Frax777', -1, (3, 34), '2022-02-10, 23:56:36')),
#     (('Piola', 'Bronko Yotte'),
#      ('Frax777', -9, (3, 25), '2022-02-10, 23:56:37')),
#     (('OK', 'Bronko Yotte'), ('Frax777', -1, (3, 38), '2022-02-11, 00:00:11')),
#     (('Cienfuegos', 'Bronko Yotte'),
#      ('Frax777', -4, (3, 34), '2022-02-11, 00:00:12')),
#     (('Van Damme / Grupo aparte', 'Bronko Yotte'),
#      ('Frax777', -1, (2, 38), '2022-02-11, 00:03:50')),
#     (('OK', 'Bronko Yotte'),
#      ('Frax777', 60, (3, 38), '2022-02-11, 00:03:51'))],
#    [(('Van Damme / Grupo aparte', 'Bronko Yotte'),
#      ('Frax777', -33, (2, 38), '2022-02-11, 00:06:29')),
#     (('Matanga', 'Bronko Yotte'),
#      ('Frax777', 0, (3, 11), '2022-02-11, 00:06:29')),
#     (('Las horas', 'Bronko Yotte'),
#      ('Frax777', -1, (3, 19), '2022-02-11, 00:09:40')),
#     (('Matanga', 'Bronko Yotte'),
#      ('Frax777', -9, (3, 11), '2022-02-11, 00:09:40')),
#     (('Dilo', 'Bronko Yotte'),
#      ('Frax777', 0, (4, 24), '2022-02-11, 00:13:00')),
#     (('Las horas', 'Bronko Yotte'),
#      ('Frax777', -65, (3, 19), '2022-02-11, 00:13:00')),
#     (('Esasi', 'Bronko Yotte'),
#      ('Frax777', -624, (3, 58), '2022-02-11, 00:17:24')),
#     (('Dilo', 'Bronko Yotte'),
#      ('Frax777', -597, (4, 24), '2022-02-11, 00:17:25')),
#     (('Esasi', 'Bronko Yotte'),
#      ('Frax777', -57162, (3, 58), '2022-02-11, 00:31:46')),
#     (('Esasi', 'Bronko Yotte'),
#      ('Frax777', 5, (3, 58), '2022-02-11, 16:28:26')),
#     (('Endorfinas', 'Bronko Yotte'),
#      ('Frax777', 83, (3, 52), '2022-02-11, 16:32:19'))],
#    [(('Puchero', 'Bronko Yotte'),
#      ('Frax777', -93, (2, 29), '2022-02-11, 16:34:48')),
#     (('Al Capone', 'Bronko Yotte'),
#      ('Frax777', -8, (4, 1), '2022-02-11, 16:38:50')),
#     (('Si bien', 'Bronko Yotte'),
#      ('Frax777', 160, (4, 9), '2022-02-11, 16:42:59'))]]),
#  ('WhiteLegioN',
#   [[(('Ma Chérie - DJ Antoine & Mad Mark 2K12 Radio Edit', 'DJ Antoine'),
#      ('WhiteLegioN', -3101, (4, 8), '2022-02-09, 19:20:27')),
#     (('Sweet Dreams (Are Made of This)', 'WINATI'),
#      ('WhiteLegioN', -158, (2, 56), '2022-02-09, 20:16:16')),
#     (('Paint The Sky', 'Mark Sixma'),
#      ('WhiteLegioN', -229, (3, 20), '2022-02-09, 20:21:50')),
#     (('BLOOD', 'Kloud'),
#      ('WhiteLegioN', 67, (3, 14), '2022-02-09, 20:28:59'))],
#    [(('This Time (Never Be Alone Again)', 'Dada Life'),
#      ('WhiteLegioN', -215, (2, 46), '2022-02-09, 20:31:06')),
#     (('Man On The Run - WHITENO1SE & System Nipel Remix', 'Dash Berlin'),
#      ('WhiteLegioN', 66, (3, 39), '2022-02-09, 20:37:27'))],
#    [(('Keep You', 'The Tech Thieves'),
#      ('WhiteLegioN', -207, (2, 34), '2022-02-09, 20:40:00')),
#     (('Cyberpunk', 'Max Brhon'),
#      ('WhiteLegioN', 83, (3, 35), '2022-02-09, 20:46:01'))],
#    [(('Black', 'Drahonn'),
#      ('WhiteLegioN', -218, (2, 0), '2022-02-09, 20:48:13')),
#     (('Тараканы (Remix)', 'PALC'),
#      ('WhiteLegioN', -102, (2, 20), '2022-02-09, 20:53:51')),
#     (("Somebody's Watching Me", 'Chico Rose'),
#      ('WhiteLegioN', -51, (4, 8), '2022-02-09, 20:57:53')),
#     (('Boulevard Of Broken Dreams', 'EQRIC'),
#      ('WhiteLegioN', -38, (4, 8), '2022-02-09, 21:02:52')),
#     (('The Climb', 'Jerome'),
#      ('WhiteLegioN', -98, (4, 8), '2022-02-09, 21:07:38')),
#     (('Inside', 'Hybrid Minds'),
#      ('WhiteLegioN', -158, (5, 7), '2022-02-09, 21:13:24')),
#     (('Montania', 'Calma Interiore'),
#      ('WhiteLegioN', -480, (2, 58), '2022-02-09, 21:21:09')),
#     (('Kaip Angelai', 'Aida Lukša'),
#      ('WhiteLegioN', 3, (3, 1), '2022-02-09, 21:32:07')),
#     (("Cloches d'Arbres", 'Auricz'),
#      ('WhiteLegioN', 2, (3, 10), '2022-02-09, 21:35:05')),
#     (('With the Moon Behind', 'Sleepy Clouds'),
#      ('WhiteLegioN', 2, (3, 33), '2022-02-09, 21:38:13')),
#     (('Pure Air', 'Calil'),
#      ('WhiteLegioN', 3, (3, 31), '2022-02-09, 21:41:44')),
#     (('Epsilon', 'WX//CLTV'),
#      ('WhiteLegioN', -26988, (3, 31), '2022-02-09, 21:45:12')),
#     (('Somebody', 'Gareth Emery'),
#      ('WhiteLegioN', 4, (3, 30), '2022-02-10, 05:18:31')),
#     (('Take All Of Me', 'Andrew Rayel'),
#      ('WhiteLegioN', 2, (3, 40), '2022-02-10, 05:21:57')),
#     (('Heart Will Follow', 'Alex Kunnari'),
#      ('WhiteLegioN', 3, (3, 36), '2022-02-10, 05:25:35')),
#     (('Drown the Sky', 'William Black'),
#      ('WhiteLegioN', 1, (3, 41), '2022-02-10, 05:29:08')),
#     (('All You Need To Know (feat. Calle Lehmann)', 'Gryffin'),
#      ('WhiteLegioN', 3, (3, 58), '2022-02-10, 05:32:48')),
#     (('This Letter', 'STANDERWICK'),
#      ('WhiteLegioN', 45, (4, 8), '2022-02-10, 05:36:43'))],
#    [(('Yesterday', 'Gareth Emery'),
#      ('WhiteLegioN', 2, (3, 19), '2022-02-10, 05:40:06')),
#     (('Know You Better', 'Stadiumx'),
#      ('WhiteLegioN', 140, (5, 54), '2022-02-10, 05:43:23'))],
#    [(('Avalanche', 'Arty'),
#      ('WhiteLegioN', 2, (3, 11), '2022-02-10, 05:46:57')),
#     (('Escape', 'Thomas Gold'),
#      ('WhiteLegioN', 1, (3, 11), '2022-02-10, 05:50:06')),
#     (('Lionheart - Tom Fall Remix', 'Gareth Emery'),
#      ('WhiteLegioN', 46, (5, 3), '2022-02-10, 05:53:16'))],
#    [(('Strangers', 'Far Out'),
#      ('WhiteLegioN', 4, (3, 8), '2022-02-10, 05:57:33')),
#     (('elise', 'Gareth Emery'),
#      ('WhiteLegioN', 2, (3, 54), '2022-02-10, 06:00:37')),
#     (('Lighter Than Air', 'Marlo'),
#      ('WhiteLegioN', 2, (3, 21), '2022-02-10, 06:04:29')),
#     (('Back To Life', 'DubVision'),
#      ('WhiteLegioN', 2, (3, 21), '2022-02-10, 06:07:48')),
#     (('Another Time - Album Edit', 'Kyau vs. Albert'),
#      ('WhiteLegioN', 2, (3, 55), '2022-02-10, 06:11:07')),
#     (('With You', 'Paul Oakenfold'),
#      ('WhiteLegioN', 2, (2, 57), '2022-02-10, 06:15:00')),
#     (('Dreams pt. II', 'Lost Sky'),
#      ('WhiteLegioN', -89, (3, 35), '2022-02-10, 06:17:55')),
#     (('Stars Collide', 'Andrew Rayel'),
#      ('WhiteLegioN', 4, (3, 43), '2022-02-10, 06:22:59')),
#     (('Daydreams - Sultan + Shepard Echoes Of Life Remix', 'Arty'),
#      ('WhiteLegioN', 3, (3, 40), '2022-02-10, 06:26:38')),
#     (('Symphony', 'Sick Individuals'),
#      ('WhiteLegioN', -1199, (3, 24), '2022-02-10, 06:30:15')),
#     (('In Your Eyes', 'Steve Brian'),
#      ('WhiteLegioN', 2, (3, 6), '2022-02-10, 06:53:38')),
#     (('Deep Blue', 'William Black'),
#      ('WhiteLegioN', 2, (3, 21), '2022-02-10, 06:56:42')),
#     (('HUMANS - Far Out Remix', 'Kloud'),
#      ('WhiteLegioN', 2, (4, 45), '2022-02-10, 07:00:01')),
#     (('Call You (feat. Nasri of MAGIC!)', 'Cash Cash'),
#      ('WhiteLegioN', 3, (3, 39), '2022-02-10, 07:04:44')),
#     (('Wait For Me', 'Steve Brian'),
#      ('WhiteLegioN', 2, (3, 37), '2022-02-10, 07:08:20')),
#     (('Long Way Home', 'Tritonal'),
#      ('WhiteLegioN', 2, (3, 34), '2022-02-10, 07:11:55')),
#     (('Hope', 'DubVision'),
#      ('WhiteLegioN', 2, (3, 23), '2022-02-10, 07:15:27')),
#     (('Meet Again', 'Mark Sixma'),
#      ('WhiteLegioN', 2, (3, 6), '2022-02-10, 07:18:48')),
#     (('For You', 'Omnia'),
#      ('WhiteLegioN', -29370, (3, 0), '2022-02-10, 07:21:52')),
#     (('Invisible Friend (feat. Sarah De Warren)', 'Lizot'),
#      ('WhiteLegioN', 184, (4, 8), '2022-02-10, 15:34:22'))],
#    [(('Work It Everyday', 'Moti'),
#      ('WhiteLegioN', 104, (4, 8), '2022-02-10, 15:35:26'))],
#    [(('Move The World (FYH294) [Favorite Of The Moment]', 'Corti Organ'),
#      ('WhiteLegioN', 13, (4, 8), '2022-02-10, 15:37:50')),
#     (('Lick It v3', 'Kaskade'),
#      ('WhiteLegioN', -17, (4, 8), '2022-02-10, 15:41:45')),
#     (('I Love The Way You Move', 'Swanky Tunes'),
#      ('WhiteLegioN', 92, (4, 8), '2022-02-10, 15:46:10'))],
#    [(('Mystery Land', 'Roman Messer'),
#      ('WhiteLegioN', 2, (3, 47), '2022-02-10, 15:48:46')),
#     (('Da Homies', 'Steve Aoki'),
#      ('WhiteLegioN', 32, (4, 8), '2022-02-10, 15:52:31'))],
#    [(('The Parade', 'Joel Corry'),
#      ('WhiteLegioN', 6, (4, 8), '2022-02-10, 15:56:07')),
#     (('Around The World (feat. NOUMENN)', 'Kshmr'),
#      ('WhiteLegioN', 1, (3, 19), '2022-02-10, 16:00:09')),
#     (('eoh', 'Olympis'),
#      ('WhiteLegioN', -45910, (2, 22), '2022-02-10, 16:03:27')),
#     (('Sunshine', 'Lance & Linton'),
#      ('WhiteLegioN', 5, (3, 27), '2022-02-11, 04:50:59')),
#     (('Stars', 'Vize'), ('WhiteLegioN', -1, (2, 45), '2022-02-11, 04:54:21')),
#     (('Amnesia (feat. GASHI)', 'Loud Luxury'),
#      ('WhiteLegioN', 54, (4, 8), '2022-02-11, 04:57:07'))],
#    [(('Supernova', 'Ansel Elgort'),
#      ('WhiteLegioN', -1, (3, 11), '2022-02-11, 05:00:21')),
#     (('Kingdom United', 'Gareth Emery'),
#      ('WhiteLegioN', -29, (5, 3), '2022-02-11, 05:03:33')),
#     (('Going Dumb', 'Alesso'),
#      ('WhiteLegioN', -14549, (2, 48), '2022-02-11, 05:09:05')),
#     (('Secret', 'Somna'), ('WhiteLegioN', 1, (3, 35), '2022-02-11, 09:14:22')),
#     (('Never Letting Go', 'Audien'),
#      ('WhiteLegioN', 3, (2, 52), '2022-02-11, 09:17:56')),
#     (("When I'm With U - RetroVision Remix", 'Tritonal'),
#      ('WhiteLegioN', 44, (3, 34), '2022-02-11, 09:20:45'))],
#    [(('Stay the Same', 'Unknown Brain'),
#      ('WhiteLegioN', 2, (3, 25), '2022-02-11, 09:23:35')),
#     (('Serious (with Matthew Koma)', 'Midnight Kids'),
#      ('WhiteLegioN', 69, (4, 8), '2022-02-11, 09:26:58'))],
#    [(('Fire & Gold', 'Morgan Page'),
#      ('WhiteLegioN', 2, (2, 34), '2022-02-11, 09:29:57')),
#     (('Sunsets', 'Nurko'),
#      ('WhiteLegioN', 2, (3, 43), '2022-02-11, 09:32:29')),
#     (('Truest Lies - Retrovision Remix', 'Far Out'),
#      ('WhiteLegioN', 69, (4, 30), '2022-02-11, 09:36:10'))],
#    [(('Turn Left', 'Snavs'),
#      ('WhiteLegioN', 2, (3, 15), '2022-02-11, 09:39:31')),
#     (('Control', 'Unknown Brain'),
#      ('WhiteLegioN', 1, (2, 46), '2022-02-11, 09:42:44')),
#     (('Over Me', 'Besomorph'),
#      ('WhiteLegioN', -9, (2, 52), '2022-02-11, 09:45:29')),
#     (('Save The World', 'Kloud'),
#      ('WhiteLegioN', 2, (3, 49), '2022-02-11, 09:48:30')),
#     (('Kids (with Miranda Glory)', 'Lione'),
#      ('WhiteLegioN', 2, (4, 20), '2022-02-11, 09:52:17')),
#     (('By My Side', 'N3WPORT'),
#      ('WhiteLegioN', 2, (3, 33), '2022-02-11, 09:56:35')),
#     (('I Will Play (Vip Remix)', 'GATTÜSO'),
#      ('WhiteLegioN', 36, (3, 44), '2022-02-11, 10:00:06'))],
#    [(('Known You Before (with Emilie Brandt)', 'Jason Ross'),
#      ('WhiteLegioN', -33869, (3, 39), '2022-02-11, 10:03:14')),
#     (('Footprints (Mixed)', 'Morgan Page'),
#      ('WhiteLegioN', 4, (3, 9), '2022-02-11, 19:31:22')),
#     (('Walk Thru Fire', 'Vicetone'),
#      ('WhiteLegioN', 2, (3, 14), '2022-02-11, 19:34:27')),
#     (('Wildest Dream', 'Thomas Gold'),
#      ('WhiteLegioN', 79, (3, 7), '2022-02-11, 19:37:39'))],
#    [(("Good Things Fall Apart (with Jon Bellion) [Tiësto's Big Room Remix]",
#       'Illenium'),
#      ('WhiteLegioN', -22, (3, 42), '2022-02-11, 19:39:27')),
#     (('Up In Smoke', 'Andy Moor'),
#      ('WhiteLegioN', 59, (4, 28), '2022-02-11, 19:43:31'))],
#    [(('We Are the Light', 'Markus Schulz'),
#      ('WhiteLegioN', 2, (3, 57), '2022-02-11, 19:47:00')),
#     (('Fly Away', 'Elle Vee'),
#      ('WhiteLegioN', 3, (3, 31), '2022-02-11, 19:50:55')),
#     (('Remember', 'Third Party'),
#      ('WhiteLegioN', -6095, (3, 48), '2022-02-11, 19:54:23')),
#     (('Thinking About You', 'Timmo Hendriks'),
#      ('WhiteLegioN', -8, (3, 9), '2022-02-11, 21:39:46')),
#     (('No Regrets (feat. Krewella)', 'Kshmr'),
#      ('WhiteLegioN', 4, (3, 4), '2022-02-11, 21:43:03')),
#     (('Beautiful', 'Moti'),
#      ('WhiteLegioN', 100, (4, 8), '2022-02-11, 21:46:03'))],
#    [(('On My Own', 'Far Out'),
#      ('WhiteLegioN', 3, (4, 30), '2022-02-11, 21:48:31')),
#     (('End of Time', 'Arc North'),
#      ('WhiteLegioN', -3, (2, 58), '2022-02-11, 21:52:58')),
#     (('Dance Monkey', 'Coopex'),
#      ('WhiteLegioN', -51420, (3, 14), '2022-02-11, 21:55:59')),
#     (('Khasarah', 'Besomorph'),
#      ('WhiteLegioN', 2, (2, 36), '2022-02-12, 12:16:13')),
#     (('Home', 'Hopex'),
#      ('WhiteLegioN', -10964, (3, 16), '2022-02-12, 12:18:47')),
#     (('Never Coming Down', 'JLV'),
#      ('WhiteLegioN', -61, (3, 15), '2022-02-12, 15:24:47')),
#     (('FreeFall', 'Sheridan Grout'),
#      ('WhiteLegioN', 77, (3, 37), '2022-02-12, 15:29:03'))],
#    [(('Ruin Your Life', 'Besomorph'),
#      ('WhiteLegioN', 22, (2, 52), '2022-02-12, 15:31:23'))],
#    [(('Deeper', 'Alok'), ('WhiteLegioN', 88, (4, 8), '2022-02-12, 15:33:53'))],
#    [(('Something I Can Dream About (ASOT 1055) [Progressive Pick]',
#       'Giuseppe Ottaviani'),
#      ('WhiteLegioN', 85, (3, 53), '2022-02-12, 15:36:33'))],
#    [(('Hall Of Fame', 'Pharaøh'),
#      ('WhiteLegioN', 0, (4, 8), '2022-02-12, 15:39:01')),
#     (('Walk Me Home', 'Said The Sky'),
#      ('WhiteLegioN', 49, (4, 8), '2022-02-12, 15:43:09'))],
#    [(('Broken - VIP', 'William Black'),
#      ('WhiteLegioN', -12, (3, 41), '2022-02-12, 15:46:28')),
#     (('Avalon 6AM - DR. DRTY Remix', 'Markus Schulz'),
#      ('WhiteLegioN', 29, (3, 57), '2022-02-12, 15:50:21'))],
#    [(('Sometimes', 'DubVision'),
#      ('WhiteLegioN', 8, (3, 23), '2022-02-12, 15:53:49')),
#     (('SHOW ME THE MADNESS', 'Libercio'),
#      ('WhiteLegioN', 58, (4, 8), '2022-02-12, 15:57:04'))],
#    [(('Empire of the Sun', 'Anton Ishutin'),
#      ('WhiteLegioN', -1701, (4, 8), '2022-02-12, 16:00:14')),
#     (('Rise Up (feat. Vamero)', 'Vinai'),
#      ('WhiteLegioN', 25, (3, 2), '2022-02-12, 16:32:43'))],
#    [(('Put Your Head On My Shoulder (feat. Laurell)', 'Costa Leon'),
#      ('WhiteLegioN', -118, (2, 22), '2022-02-12, 16:35:20')),
#     (('Big Me Up', 'Vinil'),
#      ('WhiteLegioN', -145, (2, 58), '2022-02-12, 16:39:40')),
#     (('Better Days', 'OneRepublic'),
#      ('WhiteLegioN', -44, (2, 24), '2022-02-12, 16:45:03')),
#     (('Nightlight', 'Illenium'),
#      ('WhiteLegioN', -135, (3, 42), '2022-02-12, 16:48:11')),
#     (('Tonight', 'DJ Jedy'),
#      ('WhiteLegioN', -101, (3, 18), '2022-02-12, 16:54:08')),
#     (('Улетай на крыльях ветра', 'Dabro remix'),
#      ('WhiteLegioN', -130, (2, 41), '2022-02-12, 16:59:07')),
#     (('Time', 'Erd1'), ('WhiteLegioN', -14, (4, 8), '2022-02-12, 17:03:58')),
#     (('Chemical Bond', 'Rezz'),
#      ('WhiteLegioN', 110, (4, 8), '2022-02-12, 17:08:20'))],
#    [(('Para Paradise', 'Vize'),
#      ('WhiteLegioN', -1, (2, 37), '2022-02-12, 17:10:38')),
#     (('Safe & Sound', 'lunax'),
#      ('WhiteLegioN', 114, (4, 8), '2022-02-12, 17:13:16'))],
#    [(('I Need U', 'Matt Steffanina'),
#      ('WhiteLegioN', 2, (2, 42), '2022-02-12, 17:15:30')),
#     (('Harmony (feat. Xillions)', 'Mike Williams'),
#      ('WhiteLegioN', -194, (2, 34), '2022-02-12, 17:18:10')),
#     (('Burasari', 'Roger Shah'),
#      ('WhiteLegioN', -1095, (3, 39), '2022-02-12, 17:23:58')),
#     (('Revenge', 'Solar Vision'),
#      ('WhiteLegioN', 15, (2, 54), '2022-02-12, 17:45:52')),
#     (('Stars Collide - XiJaro & Pitch Remix', 'Somna'),
#      ('WhiteLegioN', -2260, (3, 59), '2022-02-12, 17:48:31')),
#     (('Free (Talla 2XLC & Para X Original Mix)', 'Ultra'),
#      ('WhiteLegioN', -3793, (4, 8), '2022-02-12, 18:30:10')),
#     (('Full In Tension', 'Megara vs DJ Lee'),
#      ('WhiteLegioN', 74, (4, 8), '2022-02-12, 19:37:31'))],
#    [(('Home With You - Armin van Buuren pres. Rising Star Remix',
#       'Armin van Buuren'),
#      ('WhiteLegioN', -28127, (3, 33), '2022-02-12, 19:40:25')),
#     (("When I'm With You (feat. neverwaves)", 'Slander'),
#      ('WhiteLegioN', 103, (4, 8), '2022-02-13, 03:32:45'))],
#    [(("When I'm With You (feat. neverwaves)", 'Slander'),
#      ('WhiteLegioN', 26, (4, 8), '2022-02-13, 03:35:10'))],
#    [(('Drown the Sky', 'William Black'),
#      ('WhiteLegioN', -1, (3, 41), '2022-02-13, 03:35:10')),
#     (('Where The Lights Are Low', 'Toby Romeo'),
#      ('WhiteLegioN', -121, (2, 16), '2022-02-13, 03:38:52')),
#     (('Read My Mind', 'Klaas'),
#      ('WhiteLegioN', 103, (4, 8), '2022-02-13, 03:43:09'))],
#    [(('The Motto - Robin Schulz Remix', 'Tiësto'),
#      ('WhiteLegioN', 90, (4, 8), '2022-02-13, 03:45:34'))],
#    [(("Don't Laugh", 'MVDNES'),
#      ('WhiteLegioN', 74, (4, 8), '2022-02-13, 03:48:12'))],
#    [(('Ruin Your Life', 'Besomorph'),
#      ('WhiteLegioN', 18, (2, 52), '2022-02-13, 03:51:06'))],
#    [(('Sometimes', 'DubVision'),
#      ('WhiteLegioN', 1, (3, 23), '2022-02-13, 03:53:40')),
#     (('Deeper', 'Alok'), ('WhiteLegioN', 84, (4, 8), '2022-02-13, 03:57:02'))],
#    [(('I Swear', 'Younotus'),
#      ('WhiteLegioN', 116, (4, 8), '2022-02-13, 03:59:46'))],
#    [(('Abbronzatissima', 'Vinai'),
#      ('WhiteLegioN', -44931, (3, 2), '2022-02-13, 04:01:58')),
#     (('Examination Of Time - Synthsoldier Remix', 'Da Tweekaz'),
#      ('WhiteLegioN', -10, (4, 8), '2022-02-13, 16:33:51')),
#     (('Hall Of Fame', 'Pharaøh'),
#      ('WhiteLegioN', 69, (4, 8), '2022-02-13, 16:38:09'))],
#    [(('Walk Me Home', 'Said The Sky'),
#      ('WhiteLegioN', 31, (4, 8), '2022-02-13, 16:41:08'))],
#    [(('Russian Roulette', 'Whitelight'),
#      ('WhiteLegioN', 68, (4, 8), '2022-02-13, 16:44:45'))],
#    [(('Nothing Good Comes Easy', 'Felix Cartal'),
#      ('WhiteLegioN', 19, (4, 8), '2022-02-13, 16:47:45'))],
#    [(('Titanium (feat. Sia) - David Guetta & MORTEN Future Rave Remix',
#       'David Guetta'),
#      ('WhiteLegioN', 35, (4, 8), '2022-02-13, 16:51:34'))],
#    [(('Let You Go', 'Awakend'),
#      ('WhiteLegioN', -1, (3, 58), '2022-02-13, 16:55:07')),
#     (('Lonely Wolf', 'Zafrir'),
#      ('WhiteLegioN', -1, (1, 54), '2022-02-13, 16:59:06')),
#     (('Rise - Deluxe Mix', 'Lost Frequencies'),
#      ('WhiteLegioN', -48, (3, 13), '2022-02-13, 17:01:01')),
#     (('Midnight', 'Header'),
#      ('WhiteLegioN', -37608, (3, 21), '2022-02-13, 17:05:02')),
#     (('Discovery', 'Madsun'),
#      ('WhiteLegioN', 23, (4, 8), '2022-02-14, 03:35:11'))],
#    [(('Come To Life', 'Scorz'),
#      ('WhiteLegioN', -1, (3, 3), '2022-02-14, 03:38:56')),
#     (('Sorry (feat. ISÁK) - Albert Vishi Remix', 'Alan Walker'),
#      ('WhiteLegioN', 82, (4, 8), '2022-02-14, 03:42:00'))],
#    [(("When I'm Right", 'Morgan Page'),
#      ('WhiteLegioN', 23, (3, 9), '2022-02-14, 03:44:46'))],
#    [(('Here With Me - Elypsis Remix', 'Jes'),
#      ('WhiteLegioN', -1, (3, 42), '2022-02-14, 03:47:32')),
#     (('Horizon', 'Pesukone'),
#      ('WhiteLegioN', 88, (4, 8), '2022-02-14, 03:51:15'))],
#    [(('One More Time (feat. Alida) - Klingande Remix', 'Robin Schulz'),
#      ('WhiteLegioN', 82, (4, 8), '2022-02-14, 03:53:55'))],
#    [(('Stay', 'senio'), ('WhiteLegioN', -1, (3, 34), '2022-02-14, 03:56:41')),
#     (('Close To Me', 'Damo'),
#      ('WhiteLegioN', -1, (2, 37), '2022-02-14, 04:00:16')),
#     (('Sunshine - MOTi Remix', 'OneRepublic'),
#      ('WhiteLegioN', -872, (2, 24), '2022-02-14, 04:02:54')),
#     (('Electrified', 'Voster & Gallardo'),
#      ('WhiteLegioN', -43479, (4, 8), '2022-02-14, 04:19:50')),
#     (('Electrified', 'Voster & Gallardo'),
#      ('WhiteLegioN', 118, (4, 8), '2022-02-14, 16:28:37'))],
#    [(('Out Of The Sky - Chris Schweizer Remix', 'Lange'),
#      ('WhiteLegioN', -21, (4, 8), '2022-02-14, 16:30:47')),
#     (('Breathe Me In', 'ViViD'),
#      ('WhiteLegioN', 43, (4, 20), '2022-02-14, 16:35:16'))],
#    [(('Greece 2021', 'W&W'),
#      ('WhiteLegioN', 0, (3, 24), '2022-02-14, 16:38:53')),
#     (('I Would Do Anything', 'Tasadi'),
#      ('WhiteLegioN', -2, (3, 44), '2022-02-14, 16:42:17')),
#     (('Remember Me', 'Tom Westy'),
#      ('WhiteLegioN', -1, (3, 8), '2022-02-14, 16:46:03')),
#     (('Hear My Call (feat. Tyler Graves)', 'Trivecta'),
#      ('WhiteLegioN', 55, (4, 8), '2022-02-14, 16:49:12'))],
#    [(("Don't Stop", 'Going Deeper'),
#      ('WhiteLegioN', -3332, (2, 45), '2022-02-14, 16:52:25')),
#     (('Home With You - Armin van Buuren pres. Rising Star Remix',
#       'Armin van Buuren'),
#      ('WhiteLegioN', 78, (3, 33), '2022-02-14, 17:50:42'))],
#    [(('Glass Heart - Craig Connelly Remix', 'Haliene'),
#      ('WhiteLegioN', 3, (3, 47), '2022-02-14, 17:52:57')),
#     (('Spacedust', 'Talla 2XLC'),
#      ('WhiteLegioN', 41, (3, 18), '2022-02-14, 17:56:41'))],
#    [(('Time For Change', 'Ben van Gosh'),
#      ('WhiteLegioN', 58, (4, 8), '2022-02-14, 17:59:18'))],
#    [(('Red Light', 'NoMosk'),
#      ('WhiteLegioN', 3, (2, 39), '2022-02-14, 18:02:28')),
#     (('Ignite', 'Kayan Code'),
#      ('WhiteLegioN', 236, (8, 3), '2022-02-14, 18:05:04'))],
#    [(('Tempesta', 'Corrado Baggieri'),
#      ('WhiteLegioN', 46, (4, 8), '2022-02-14, 18:09:11'))],
#    [(('Through The Dark', 'Rene Dale'),
#      ('WhiteLegioN', 21, (4, 8), '2022-02-14, 18:12:33'))],
#    [(('T2 [Trip]', 'Scot Project'),
#      ('WhiteLegioN', 45, (4, 38), '2022-02-14, 18:16:20'))],
#    [(('You - Intro Edit', 'Avar'),
#      ('WhiteLegioN', -77, (4, 8), '2022-02-14, 18:20:13')),
#     (('Yama', 'Armin van Buuren'),
#      ('WhiteLegioN', 19, (3, 33), '2022-02-14, 18:25:38'))],
#    [(('Place in the Stars', 'Craig Connelly'),
#      ('WhiteLegioN', -67821, (4, 33), '2022-02-14, 18:28:52')),
#     (('Thank You - TikTok Edit', 'Max + Johann'),
#      ('WhiteLegioN', -1195, (4, 8), '2022-02-15, 13:23:46')),
#     (('Euphorica', 'Solar Vision'),
#      ('WhiteLegioN', -95, (2, 54), '2022-02-15, 13:47:49')),
#     (('Eternal Spirit (Original Mix)', 'Talla 2XLC'),
#      ('WhiteLegioN', 2, (3, 31), '2022-02-15, 13:52:18')),
#     (('People', 'Airwalk3r'),
#      ('WhiteLegioN', 2, (2, 50), '2022-02-15, 13:55:47')),
#     (('More Than Ever', 'Doppenberg'),
#      ('WhiteLegioN', 3, (2, 55), '2022-02-15, 13:58:35')),
#     (('People', 'Airwalk3r'),
#      ('WhiteLegioN', 0, (2, 50), '2022-02-15, 13:58:37')),
#     (('Full Of Questions', 'Yelow'),
#      ('WhiteLegioN', -11455, (4, 8), '2022-02-15, 14:01:27')),
#     (('The Rebel', 'Talla 2XLC'),
#      ('WhiteLegioN', -71505, (3, 35), '2022-02-15, 17:16:30')),
#     (("I've Been Gone So Long (Original Mix)", 'Talla 2XLC'),
#      ('WhiteLegioN', -319, (3, 35), '2022-02-16, 13:11:50')),
# ...
#      ('23kulpamens', 199, (6, 24), '2020-01-24, 01:43:27'))],
#    [(('I Dreamt We Spoke Again', 'Death Cab for Cutie'),
#      ('23kulpamens', -89, (3, 4), '2020-01-24, 01:46:32')),
#     (('When I Get Out', 'Hatchie'),
#      ('23kulpamens', -21, (4, 33), '2020-01-24, 01:51:05')),
#     (('Liar', 'Ex:Re'), ('23kulpamens', 79, (4, 54), '2020-01-24, 01:55:59'))],
#    [(('The Closest Thing To Living', 'Wild Nothing'),
#      ('23kulpamens', -23, (5, 18), '2020-01-24, 01:59:34')),
#     (('Metamorphosis', 'John Grant'),
#      ('23kulpamens', 219, (5, 41), '2020-01-24, 02:05:15'))],
#    [(('Greenpoint Gothic', 'Deerhunter'),
#      ('23kulpamens', -258, (2, 2), '2020-01-24, 02:07:17')),
#     (('Now Or Never Now', 'Metric'),
#      ('23kulpamens', 151, (6, 20), '2020-01-24, 02:13:37'))],
#    [(('When We Drive', 'Death Cab for Cutie'),
#      ('23kulpamens', -16, (3, 49), '2020-01-24, 02:17:26')),
#     (('Secret', 'Hatchie'),
#      ('23kulpamens', 43, (4, 4), '2020-01-24, 02:21:31'))],
#    [(('Whisper', 'Still Corners'),
#      ('23kulpamens', -56, (3, 21), '2020-01-24, 02:24:52')),
#     (("I Can't Keep You", 'Ex:Re'),
#      ('23kulpamens', -11, (4, 17), '2020-01-24, 02:29:09')),
#     (('Violet Noon', 'The KVB'),
#      ('23kulpamens', 37, (4, 28), '2020-01-24, 02:33:37'))],
#    [(('Oscillation', 'Wild Nothing'),
#      ('23kulpamens', -148, (3, 54), '2020-01-24, 02:37:28')),
#     (('Love Is Magic', 'John Grant'),
#      ('23kulpamens', 254, (6, 22), '2020-01-24, 02:43:50'))],
#    [(('Washing Machine Heart', 'Mitski'),
#      ('23kulpamens', -118, (2, 8), '2020-01-24, 02:45:58')),
#     (('Die Happy', 'Metric'),
#      ('23kulpamens', 53, (4, 6), '2020-01-24, 02:50:04'))],
#    [(('Sandman', 'Broncho'),
#      ('23kulpamens', -76, (3, 12), '2020-01-24, 02:53:17')),
#     (('Summer Years', 'Death Cab for Cutie'),
#      ('23kulpamens', -70, (4, 28), '2020-01-24, 02:57:45')),
#     (('Welcome to Slow Air', 'Still Corners'),
#      ('23kulpamens', 41, (5, 37), '2020-01-24, 03:03:23'))],
#    [(('Weightless', 'Washed Out'),
#      ('23kulpamens', -72, (4, 55), '2020-01-24, 03:08:19')),
#     (('Cerulean', 'The KVB'),
#      ('23kulpamens', -23290, (6, 7), '2020-01-24, 03:14:26')),
#     (('Partners In Motion', 'Wild Nothing'),
#      ('23kulpamens', -34, (4, 23), '2020-01-24, 09:48:43')),
#     (('Wheel of Misfortune', 'Wild Nothing'),
#      ('23kulpamens', 10, (4, 16), '2020-01-24, 09:53:40')),
#     (('Shallow Water', 'Wild Nothing'),
#      ('23kulpamens', -85478, (4, 8), '2020-01-24, 09:57:46')),
#     (('Silence (Feat. Sarah McLachlan) [Alyx Ander vs. Delerium] [Radio Edit]',
#       'Delerium'),
#      ('23kulpamens', 186, (3, 39), '2020-01-25, 09:46:32'))],
#    [(('Silence (Feat. Sarah McLachlan) [Alyx Ander vs. Delerium] [Radio Edit]',
#       'Delerium'),
#      ('23kulpamens', -180, (3, 39), '2020-01-25, 09:47:05')),
#     (('Silence (feat. Sarah McLachlan)', 'Delerium'),
#      ('23kulpamens', -170576, (6, 33), '2020-01-25, 09:53:44')),
#     (('Silence (Feat. Sarah McLachlan) [Alyx Ander vs. Delerium] [Radio Edit]',
#       'Delerium'),
#      ('23kulpamens', 16, (3, 39), '2020-01-27, 09:23:13'))],
#    [(('Whisper', 'Denis Kenzo, Angel Falls'),
#      ('23kulpamens', 0, (4, 8), '2020-01-27, 09:26:36')),
#     (('Omen In The Rain', 'Myon, Alissa Feudo'),
#      ('23kulpamens', -990129, (4, 8), '2020-01-27, 09:30:44')),
#     (('In the Middle of the Night', 'Still Corners'),
#      ('23kulpamens', -74, (3, 39), '2020-02-07, 20:37:01')),
#     (('The Message', 'Still Corners'),
#      ('23kulpamens', 48, (4, 52), '2020-02-07, 20:41:54'))],
#    [(('Sad Movies', 'Still Corners'),
#      ('23kulpamens', -94, (4, 4), '2020-02-07, 20:45:58')),
#     (('Welcome to Slow Air', 'Still Corners'),
#      ('23kulpamens', 3, (5, 37), '2020-02-07, 20:51:36')),
#     (('Black Lagoon', 'Still Corners'),
#      ('23kulpamens', 68, (5, 33), '2020-02-07, 20:57:10'))],
#    [(('Dreamlands', 'Still Corners'),
#      ('23kulpamens', 64, (4, 25), '2020-02-07, 21:01:35'))],
#    [(('Whisper', 'Still Corners'),
#      ('23kulpamens', 53, (3, 21), '2020-02-07, 21:04:56'))],
#    [(('Fade Out', 'Still Corners'),
#      ('23kulpamens', -73, (2, 28), '2020-02-07, 21:07:24')),
#     (('The Photograph', 'Still Corners'),
#      ('23kulpamens', 35, (3, 40), '2020-02-07, 21:11:05'))],
#    [(('Long Goodbyes', 'Still Corners'),
#      ('23kulpamens', -50, (3, 1), '2020-02-07, 21:14:10')),
#     (('Sleepwalking', 'Jonathan Bree'),
#      ('23kulpamens', -219, (3, 50), '2020-02-07, 21:18:01')),
#     (('Denmark / Van Gogh & Gone', 'Psychedelic Porn Crumpets'),
#      ('23kulpamens', 230, (7, 29), '2020-02-07, 21:25:30'))],
#    [(("It's Personal", 'The Radio Dept.'),
#      ('23kulpamens', -82, (3, 38), '2020-02-07, 21:29:09')),
#     (('Vinta', 'Crumb'),
#      ('23kulpamens', -39, (4, 59), '2020-02-07, 21:34:09')),
#     (('Welcome to Slow Air', 'Still Corners'),
#      ('23kulpamens', 17, (5, 37), '2020-02-07, 21:39:47'))],
#    [(('Space Song', 'Beach House'),
#      ('23kulpamens', 126, (5, 20), '2020-02-07, 21:45:07'))],
#    [(('Confirmation', 'Wild Nothing'),
#      ('23kulpamens', -173, (3, 13), '2020-02-07, 21:48:21')),
#     (("It's Late", 'A Beacon School'),
#      ('23kulpamens', 172, (6, 6), '2020-02-07, 21:54:27'))],
#    [(('Bones', 'Crumb'),
#      ('23kulpamens', -48, (3, 13), '2020-02-07, 21:57:41')),
#     (('Chances', 'Many Voices Speak'),
#      ('23kulpamens', -24, (4, 1), '2020-02-07, 22:01:42')),
#     (('Dreamlands', 'Still Corners'),
#      ('23kulpamens', -7, (4, 25), '2020-02-07, 22:06:07')),
#     (('They Always Fly Away', 'Blouse'),
#      ('23kulpamens', 33, (4, 32), '2020-02-07, 22:10:39'))],
#    [(('Drunk In L.A.', 'Beach House'),
#      ('23kulpamens', 1, (5, 20), '2020-02-07, 22:14:38')),
#     (('Nocturne', 'Wild Nothing'),
#      ('23kulpamens', 113, (5, 18), '2020-02-07, 22:19:57'))],
#    [(('Hotel Delmano', 'MUNYA'),
#      ('23kulpamens', -10, (4, 8), '2020-02-07, 22:23:22')),
#     (('Body Language', 'Helena Deland'),
#      ('23kulpamens', 194, (4, 17), '2020-02-07, 22:27:40'))],
#    [(('Body Language', 'Helena Deland'),
#      ('23kulpamens', -58, (4, 17), '2020-02-07, 22:28:43')),
#     (('In the Kingdom', 'Mazzy Star'),
#      ('23kulpamens', 113, (5, 14), '2020-02-07, 22:33:58'))],
#    [(('Whisper', 'Still Corners'),
#      ('23kulpamens', -183, (3, 21), '2020-02-07, 22:37:19')),
#     (('Nocturne', 'Deerhunter'),
#      ('23kulpamens', 132, (6, 24), '2020-02-07, 22:43:43'))],
#    [(('Black Car', 'Beach House'),
#      ('23kulpamens', 16, (4, 11), '2020-02-07, 22:47:55'))],
#    [(('Rheya', 'Wild Nothing'),
#      ('23kulpamens', -43, (3, 54), '2020-02-07, 22:51:50')),
#     (('Take It All', 'Helena Deland'),
#      ('23kulpamens', -8, (4, 36), '2020-02-07, 22:56:27')),
#     (('Stars And Moons', 'Dizzy'),
#      ('23kulpamens', 45, (4, 8), '2020-02-07, 23:01:11'))],
#    [(('Before', 'Vök'), ('23kulpamens', -61, (3, 25), '2020-02-07, 23:04:34')),
#     (('Midnight Drive', 'Still Corners'),
#      ('23kulpamens', -48, (4, 24), '2020-02-07, 23:09:00')),
#     (('Set in Stone', 'Milk & Bone'),
#      ('23kulpamens', 64, (5, 12), '2020-02-07, 23:14:12'))],
#    [(('The Hours', 'Beach House'),
#      ('23kulpamens', -9, (4, 12), '2020-02-07, 23:18:20')),
#     (('Partners In Motion', 'Wild Nothing'),
#      ('23kulpamens', 81, (4, 23), '2020-02-07, 23:22:41'))],
#    [(('Bedroom Talks', 'Fazerdaze'),
#      ('23kulpamens', -45, (3, 2), '2020-02-07, 23:25:43')),
#     (('Some Time Alone, Alone', "Melody's Echo Chamber"),
#      ('23kulpamens', -43, (3, 46), '2020-02-07, 23:29:30')),
#     (('Baby', 'Helena Deland'),
#      ('23kulpamens', 37, (4, 29), '2020-02-07, 23:33:59'))],
#    [(('Sun Was High (So Was I)', 'Small Black'),
#      ('23kulpamens', -29, (3, 51), '2020-02-07, 23:37:51')),
#     (('Adrift', 'Vök'), ('23kulpamens', 26, (4, 20), '2020-02-07, 23:42:11'))],
#    [(('Speaking Terms', 'Snail Mail'),
#      ('23kulpamens', -26, (3, 53), '2020-02-07, 23:46:05')),
#     (('Strange Pleasures', 'Still Corners'),
#      ('23kulpamens', -423365, (5, 12), '2020-02-07, 23:50:24')),
#     (('Strange Pleasures', 'Still Corners'),
#      ('23kulpamens', -157, (5, 12), '2020-02-12, 21:31:41')),
#     (('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -188, (7, 46), '2020-02-12, 21:39:30')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 203, (10, 58), '2020-02-12, 21:50:24'))],
#    [(('Restless', 'Hinkstep'),
#      ('23kulpamens', -14, (7, 39), '2020-02-12, 21:57:59')),
#     (('September Song', 'Hinkstep'),
#      ('23kulpamens', -37, (7, 46), '2020-02-12, 22:05:52')),
#     (('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -70108, (7, 46), '2020-02-12, 22:14:15')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', -58, (10, 58), '2020-02-13, 17:50:29')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 203, (10, 58), '2020-02-13, 18:02:25'))],
#    [(('Restless', 'Hinkstep'),
#      ('23kulpamens', 47, (7, 39), '2020-02-13, 18:10:00'))],
#    [(('September Song', 'Hinkstep'),
#      ('23kulpamens', 281, (7, 46), '2020-02-13, 18:16:52'))],
#    [(('September Song', 'Hinkstep'),
#      ('23kulpamens', -37, (7, 46), '2020-02-13, 18:19:57')),
#     (('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -331, (7, 46), '2020-02-13, 18:28:20')),
#     (('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -14547, (7, 46), '2020-02-13, 18:41:37')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 203, (10, 58), '2020-02-13, 22:51:50'))],
#    [(('Restless', 'Hinkstep'),
#      ('23kulpamens', 206, (7, 39), '2020-02-13, 22:59:25'))],
#    [(('September Song', 'Hinkstep'),
#      ('23kulpamens', -192, (7, 46), '2020-02-13, 23:03:38')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 203, (10, 58), '2020-02-13, 23:14:36'))],
#    [(('Restless', 'Hinkstep'),
#      ('23kulpamens', -335, (7, 39), '2020-02-13, 23:22:11')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 203, (10, 58), '2020-02-13, 23:35:25'))],
#    [(('Restless', 'Hinkstep'),
#      ('23kulpamens', -14, (7, 39), '2020-02-13, 23:43:00')),
#     (('September Song', 'Hinkstep'),
#      ('23kulpamens', -37, (7, 46), '2020-02-13, 23:50:53')),
#     (('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', 100, (7, 46), '2020-02-13, 23:59:16'))],
#    [(('Opium', 'Hinkstep'),
#      ('23kulpamens', 547, (10, 58), '2020-02-14, 00:05:22'))],
#    [(('The Missing (Origin 2006)', 'Solar Fields'),
#      ('23kulpamens', 64, (9, 36), '2020-02-14, 00:07:13'))],
#    [(('Sol', 'Solar Fields'),
#      ('23kulpamens', -73, (8, 23), '2020-02-14, 00:15:45')),
#     (('The Missing (Origin 2006)', 'Solar Fields'),
#      ('23kulpamens', 12, (9, 36), '2020-02-14, 00:25:21')),
#     (('Unite (Origin 2007)', 'Solar Fields'),
#      ('23kulpamens', 146, (9, 23), '2020-02-14, 00:34:45'))],
#    [(('The Road to Nothingness', 'Solar Fields'),
#      ('23kulpamens', -75501, (6, 46), '2020-02-14, 00:41:42')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 204, (10, 58), '2020-02-14, 21:46:49'))],
#    [(('Restless', 'Hinkstep'),
#      ('23kulpamens', -15, (7, 39), '2020-02-14, 21:54:23')),
#     (('September Song', 'Hinkstep'),
#      ('23kulpamens', -37, (7, 46), '2020-02-14, 22:02:17')),
#     (('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -1820, (7, 46), '2020-02-14, 22:10:40')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 185, (10, 58), '2020-02-14, 22:48:46'))],
#    [(('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -188, (7, 46), '2020-02-14, 22:56:39')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 204, (10, 58), '2020-02-14, 23:07:33'))],
#    [(('Restless', 'Hinkstep'),
#      ('23kulpamens', -15, (7, 39), '2020-02-14, 23:15:07')),
#     (('September Song', 'Hinkstep'),
#      ('23kulpamens', -37, (7, 46), '2020-02-14, 23:23:01')),
#     (('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -830, (7, 46), '2020-02-14, 23:31:24')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 190, (10, 58), '2020-02-14, 23:53:00'))],
#    [(('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -188, (7, 46), '2020-02-15, 00:00:48')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', 203, (10, 58), '2020-02-15, 00:11:42'))],
#    [(('Restless', 'Hinkstep'),
#      ('23kulpamens', -14, (7, 39), '2020-02-15, 00:19:17')),
#     (('September Song', 'Hinkstep'),
#      ('23kulpamens', 40, (7, 46), '2020-02-15, 00:27:10'))],
#    [(('Whispering Pines', 'Hinkstep'),
#      ('23kulpamens', -191, (7, 46), '2020-02-15, 00:34:16')),
#     (('Opium', 'Hinkstep'),
#      ('23kulpamens', -644661, (10, 58), '2020-02-15, 00:45:13')),
#     (('Í TOKUNI', 'Eivør'),
#      ('23kulpamens', -3183, (4, 8), '2020-02-22, 12:00:32')),
#     (('SALT', 'Eivør'), ('23kulpamens', 104, (4, 8), '2020-02-22, 12:57:43'))],
#    [(('SALT', 'Eivør'),
#      ('23kulpamens', -1203, (4, 8), '2020-02-22, 13:00:07')),
#     (('Trøllabundin', 'Eivør Pálsdóttir'),
#      ('23kulpamens', -786, (2, 59), '2020-02-22, 13:24:18')),
#     (('Return to Tunguska (feat. Shpongle & Dave Gilmour)',
#       'The Alan Parsons Project'),
#      ('23kulpamens', -3, (4, 8), '2020-02-22, 13:40:23')),
#     (('Return to Tunguska (feat. Shpongle & Dave Gilmour)',
#       'The Alan Parsons Project'),
#      ('23kulpamens', -42, (4, 8), '2020-02-22, 13:44:34')),
#     (('SILVITNI', 'Eivør'),
#      ('23kulpamens', 40, (4, 8), '2020-02-22, 13:49:24'))],
#    [(('BROTIN', 'Eivør'),
#      ('23kulpamens', -28, (4, 8), '2020-02-22, 13:52:52')),
#     (('SALT', 'Eivør'), ('23kulpamens', 11, (4, 8), '2020-02-22, 13:57:28')),
#     (('MJØRKAFLÓKAR', 'Eivør'),
#      ('23kulpamens', 68, (4, 8), '2020-02-22, 14:01:25'))],
#    [(('PETTI FYRI PETTI', 'Eivør'),
#      ('23kulpamens', 79, (4, 8), '2020-02-22, 14:04:25'))],
#    [(('RØTTU SKÓGVARNIR', 'Eivør'),
#      ('23kulpamens', 36, (4, 8), '2020-02-22, 14:07:14'))],
#    [(('Í TOKUNI', 'Eivør'),
#      ('23kulpamens', -48, (4, 8), '2020-02-22, 14:10:46')),
#     (('Verd Mín', 'Eivør'),
#      ('23kulpamens', -134, (4, 8), '2020-02-22, 14:15:42')),
#     (('Slør', 'Eivør'),
#      ('23kulpamens', -1555, (4, 8), '2020-02-22, 14:22:04')),
#     (('Arisen My Senses', 'Björk'),
#      ('23kulpamens', 114, (4, 8), '2020-02-22, 14:52:07'))],
#    [(('Jungle Drum', 'Emilíana Torrini'),
#      ('23kulpamens', -2, (2, 12), '2020-02-22, 14:54:21')),
#     (("Pema's Theme", 'Cyril Morin'),
#      ('23kulpamens', 1, (2, 13), '2020-02-22, 14:56:35')),
#     (('Maniwall', 'Cyril Morin'),
#      ('23kulpamens', -82, (2, 10), '2020-02-22, 14:58:47')),
#     (('The Eagle', 'Cyril Morin'),
#      ('23kulpamens', -1446, (1, 29), '2020-02-22, 15:02:19')),
#     (('The Eagle', 'Cyril Morin'),
#      ('23kulpamens', -3786, (1, 29), '2020-02-22, 15:27:54')),
#     (('Black Lagoon', 'Still Corners'),
#      ('23kulpamens', -191, (5, 33), '2020-02-22, 16:32:29')),
#     (('Rogue Bagel', 'Ott'),
#      ('23kulpamens', 162, (8, 33), '2020-02-22, 16:41:13'))],
#    [(('Welcome to Slow Air', 'Still Corners'),
#      ('23kulpamens', 248, (5, 37), '2020-02-22, 16:47:04'))],
#    [(('The Eagle', 'Cyril Morin'),
#      ('23kulpamens', 20, (1, 29), '2020-02-22, 16:48:33'))],
#    [(('The Return', 'Cyril Morin'),
#      ('23kulpamens', -2930, (1, 0), '2020-02-22, 16:49:42')),
#     (('Deep Jungle Walk', 'Astrix'),
#      ('23kulpamens', 40, (9, 15), '2020-02-22, 17:39:32'))],
#    [(('Devotion (Morten Granau & Zyce Remix)', 'Liquid Soul'),
#      ('23kulpamens', -543, (4, 8), '2020-02-22, 17:48:07')),
#     (('Shamanic Tales', 'Astrix'),
#      ('23kulpamens', 226, (13, 1), '2020-02-22, 18:01:18'))],
#    [(('Deep Jungle Walk', 'Astrix'),
#      ('23kulpamens', 66, (9, 15), '2020-02-22, 18:10:33'))],
#    [(('Alien Turned Human', 'Astrix'),
#      ('23kulpamens', 207, (8, 8), '2020-02-22, 18:18:42'))],
#    [(('Chillektron', 'Óperentzia'),
#      ('23kulpamens', 295, (7, 4), '2020-02-22, 18:23:23'))],
#    [(('Shivaya', 'Óperentzia'),
#      ('23kulpamens', 66, (7, 19), '2020-02-22, 18:25:32'))],
#    [(('Shivaya', 'Óperentzia'),
#      ('23kulpamens', -444245, (7, 19), '2020-02-22, 18:31:45')),
#     (('Like a Mirror', 'Hinkstep'),
#      ('23kulpamens', 156, (11, 8), '2020-02-27, 22:03:09'))],
#    [(('Within Your Echoes', 'Hinkstep'),
#      ('23kulpamens', 44, (8, 32), '2020-02-27, 22:11:41'))],
#    [(('A Little Tree', 'Hinkstep'),
#      ('23kulpamens', -57, (7, 47), '2020-02-27, 22:19:29')),
#     (('Blend In With The Crowd', 'Hinkstep'),
#      ('23kulpamens', 510, (11, 9), '2020-02-27, 22:28:13'))]])]

# %% [markdown]
# ## Statistics about listening sessions

# %% [markdown]
# average number of tracks
#
# average session per user
#
# session lengths

# %%
def avg_tracks(x):
  r,c = 0, 1
  for y in x:
    r += len(y)
    c += 1
  return round(r/c, 3)

user_avg_tracks = user_sessions.map(lambda x: (x[0], avg_tracks(x[1])))
user_avg_tracks.take(10)
# Out:
# [('Frax777', 5.211),
#  ('WhiteLegioN', 3.072),
#  ('jumd', 3.947),
#  ('kurtphyre', 2.235),
#  ('stephiesama', 2.882),
#  ('abernes', 2.1),
#  ('Gunthar666', 6.636),
#  ('junjindua', 2.848),
#  ('jreisner', 5.352),
#  ('23kulpamens', 2.552)]

# %%
def avg_session(x):
  r,c = 0, 1
  for y in x:
    r += len(x)
    c += 1
  return round(r/c, 3)

user_avg_session = user_sessions.map(lambda x: (x[0], avg_session(x[1])))
user_avg_session.take(10)
# Out:
# [('Frax777', 55.018),
#  ('WhiteLegioN', 95.01),
#  ('jumd', 73.013),
#  ('kurtphyre', 130.008),
#  ('stephiesama', 100.01),
#  ('abernes', 138.007),
#  ('Gunthar666', 42.023),
#  ('junjindua', 103.01),
#  ('jreisner', 52.019),
#  ('23kulpamens', 114.009)]

# %%
to_sec = lambda x: x[0]*60+x[1]

def avg_session_len(x):
  r,c = 0, 1
  for y in x:
    r += to_sec(y[0][1][2])
    c += 1
  return round(r/c, 3)

user_avg_session_len = user_sessions.map(lambda x: (x[0], avg_session_len(x[1])))
user_avg_session_len.take(10)
# Out:
# [('Frax777', 217.193),
#  ('WhiteLegioN', 220.99),
#  ('jumd', 259.72),
#  ('kurtphyre', 270.038),
#  ('stephiesama', 267.549),
#  ('abernes', 203.679),
#  ('Gunthar666', 235.523),
#  ('junjindua', 185.59),
#  ('jreisner', 215.481),
#  ('23kulpamens', 277.172)]

# %% [markdown]
# # Save results to Data Lake

# %%
user_sessions_collect = user_sessions.collect()

user_sessions_stats = {
    'user_avg_tracks': user_avg_tracks.collect(),
    'user_avg_session': user_avg_session.collect(),
    'user_avg_session_len' : user_avg_session_len.collect()
    }

# %%
dest_path = 'listening_sessions' + '/'
ls_path = dest_path + 'listening_sessions' + '/'
ls_stats_path = dest_path + 'listening_sessions_statistics' + '/'

for key,value in user_sessions_stats.items():
  storage.write(value, ls_stats_path+f"listening_sessions_{key}")

for user in user_sessions_collect:
  storage.write(user, ls_path+f"listening_sessions_{user[0]}")
